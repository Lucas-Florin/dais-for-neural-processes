# %%
import math
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import multivariate_normal
from scipy.stats import norm as univariate_normal

import pandas as pd
import seaborn as sns

import random

# Generate noisy dataset
seed = 42
np.random.seed(seed)

n_datapoints = 1000
intercept = -0.7
slope = 0.9
noise_std_dev = 0.5
noise_var = noise_std_dev**2
lower_bound = -1.5
upper_bound = 1.5


train_points = np.random.uniform(lower_bound, upper_bound, n_datapoints)
noisy_labels = slope * train_points + intercept + np.random.normal(0, noise_std_dev, n_datapoints)
true_labels = slope * train_points + intercept

# Plot the dataset
plt.figure(figsize=(10,7))
plt.plot(train_points, true_labels, color='r', label="True values")
plt.scatter(train_points, noisy_labels, label="Noise corrupted values")
plt.xlabel("Features")
plt.ylabel("Labels")
plt.title("Real function along with noisy targets")
plt.legend();

# %%
feature_dim = 2

feature_matrix = np.stack((np.ones(n_datapoints),train_points), axis=1)

precision = 0.2
prior_mean = np.zeros(feature_dim)
prior_cov = np.identity(feature_dim) * (1.0/precision)

prior = multivariate_normal(prior_mean, prior_cov)

# %%
inverse_mat = np.linalg.inv(np.dot(feature_matrix.T, feature_matrix) + noise_var * precision * np.identity(feature_dim))

# %%
# Compute the posterior distribution
posterior_mean = np.dot(inverse_mat, np.dot(feature_matrix.T, noisy_labels))
posterior_cov = noise_var * inverse_mat

posterior = multivariate_normal(posterior_mean, posterior_cov)

# Plot the posterior distribution
fig = plt.figure()
mesh_features, mesh_labels = np.mgrid[-1.0:-0.5:.01, 0.5:1.0:.01]
pos = np.dstack((mesh_features, mesh_labels))
plt.contourf(mesh_features, mesh_labels, posterior.pdf(pos), levels=15)
plt.scatter(intercept, slope, color='red', label="True parameter values")
plt.title("posterior distribution")
plt.xlabel("Intercept")
plt.ylabel("Slope")
plt.legend();

# %%
# Check posterior predictive distribution
n_test_points = 10

test_points = np.random.uniform(lower_bound, upper_bound, n_test_points)

# %%
all_rows = []
sample_size = 1000

true_labels = slope * test_points + intercept

for point in test_points:
    test_features = np.stack((np.ones(1), np.array([point])), axis=1)
    pred_mean = test_features.dot(posterior_mean)
    pred_cov = test_features.dot(posterior_cov.dot(test_features.T)) + noise_var
    predictive = univariate_normal(pred_mean.flatten(), math.sqrt(pred_cov))
    
    sample_predicted_labels = predictive.rvs(size=sample_size)
    for label in sample_predicted_labels:
        all_rows.append([point, label])
    
all_data = pd.DataFrame(all_rows, columns=["feature", "label"]) 
sns.displot(data=all_data, x="feature", y="label")
plt.scatter(x=test_points, y=true_labels, color="red", label="True values")
plt.title("Predictive posterior distributions")
plt.legend()
plt.plot();

# %%
# Compute log marginal likelihood
log_ml = 0
for i in range(0, n_datapoints):
    train_features = np.stack((np.ones(1), np.array([train_points[i]])), axis=1)
    pred_mean = train_features.dot(posterior_mean)
    pred_cov = train_features.dot(posterior_cov.dot(train_features.T)) + noise_var
    predictive = univariate_normal(pred_mean, math.sqrt(pred_cov))
    
    true_label = train_points[i] * slope + intercept
    # print("true output: " + str(true_label), "pred mean: " + str(pred_mean), "pred covariance: " + str(pred_cov), "pred probability: " + str(predictive.pdf(true_label)))
    log_ml += math.log(predictive.pdf(true_label))
    
print("Log Marginal Likelihood on the training set: " + str(log_ml))
# Out:
# Log Marginal Likelihood on the training set: -232.70006064745112

# %% [markdown]
# # Harmonic Mean Estimator
#
# We want to estimate the marginal likelihood, because normally it is impossible to analytically calculate its exact value for arbitrary distributions. The Harmonic Mean Estimator is an estimator based on Simple Importance Sampling (SIS), which can estimate the marginal likelihood through the posterior and the prior. The formula below shows the relation between these three distributions:
# \begin{equation}
#  E_{\omega \sim p(\omega|y)}\left[ \frac{p(\omega)}{p(\omega, y)}\right] = \frac{1}{p(y)}
# \end{equation}
#
# Following this formula we first sample from the posterior $p(\omega, y)$ and then calculate the ratio of prior and posterior, which is the reciprocal of the predictive distribution:
# \begin{equation}
#  \frac{p(\omega)}{p(\omega,y)} = \frac{1}{p(y|\omega)}
# \end{equation}
#
# Therefore we evaluate the sample-specific predictive distribution at the target location and add the results together to obtain the unbiased estimation of the reciprocal of the marginal likelihood.
#
# To compute the predictive distribution over all data points with given model parameter, we use the following formula:
# \begin{equation}
#  p(y|\omega) = \prod_{i = 1}^{N}p(y_i|\omega) = \exp{\sum_{i = 1}^{N} \log(p(y_i|\omega))}
# \end{equation}
# We first sum up in log space, because directly calculating the product of the value for each data point might lead to numerical underflow.

# %%
# Harmonic Mean Estimator

# Samples need to be from the posterior
def harmonic_mean_estimator(samples):
    denominator = 0
    for k in range(0, len(samples)):
        sum_logs = 0

        print("current sample: " + str(samples[k]))
        for i in range(0, n_datapoints):
            train_features = np.stack((np.ones(1), np.array([train_points[i]])), axis=1)
            true_label = train_points[i] * slope + intercept
            pred_mean = train_features.dot(samples[k])
            pred_cov = noise_var
            predictive = univariate_normal(pred_mean, math.sqrt(pred_cov))

            sum_logs += math.log(predictive.pdf(true_label))

        dataset_likelihood = math.exp(sum_logs)
        denominator += 1.0 / dataset_likelihood

    ML_estimate = K / denominator
    return ML_estimate


# With ground truth samples
K = 20
true_samples = posterior.rvs(size=K)
ML_estimate = harmonic_mean_estimator(true_samples)
print("Estimated Log Marginal Likelihood on the training set: " + str(math.log(ML_estimate)))
# Out:
# current sample: [-0.63532621  0.86021307]
# current sample: [-0.63706157  0.90160621]
# current sample: [-0.631156    0.84338768]
# current sample: [-0.64747054  0.90238564]
# current sample: [-0.65696843  0.89895863]
# current sample: [-0.66734052  0.84213635]
# current sample: [-0.67077621  0.90807742]
# current sample: [-0.65074153  0.87407177]
# current sample: [-0.65936453  0.86580412]
# current sample: [-0.65991894  0.87653632]
# current sample: [-0.65107542  0.84821059]
# current sample: [-0.63526462  0.89171688]
# current sample: [-0.67267606  0.86204945]
# current sample: [-0.62735336  0.86599867]
# current sample: [-0.63881137  0.88436283]
# current sample: [-0.6427027   0.88929658]
# current sample: [-0.64063339  0.87502318]
# current sample: [-0.6746455   0.86709646]
# current sample: [-0.6302789   0.88471381]
# current sample: [-0.64089337  0.85248252]
# Estimated Log Marginal Likelihood on the training set: -237.80814434798125

# %% [markdown]
# # Markov Chain Monte Carlo
# In practice we usually cannot sample from the true posterior, because we cannot compute it analytically. Therefore, we use Markov Chain Monte Carlo (MCMC) sampling to obtain approximate samples from the posterior without knowing its true form. The only constraint is that we have to be able to evaluate a function $f$ that is proportional to the posterior. The posterior can be decomposed using Bayes rule to this:
# \begin{equation}
# p(w|X, y) = {p(y|X, w)p(w) \over p(y|X)} = {p(y|X, w)p(w) \over \int p(y|X, w)p(w)dw}
# \end{equation}
# Even if we do not know the analytical form of the posterior because we cannot solve the integral in the denominator, we can still evaluate the numerator. Since it is proportional to the posterior, it is valid for us to define
# \begin{equation}
# f(w) = p(y|X, w)p(w)
# \end{equation}
#
# We use the Metropolis algorithm to define our acceptance probabilities and thereby also our transition probabilities of the Markov Chain. The idea is to define the transition probabilities such that the Markov Chain's stationary distribution is identical to our target distribution, the posterior distribution. This can be achieved by fulfilling the "detailed balance condition": $p(a)T(a \rightarrow b) = p(b)T(b \rightarrow a)$, where $T(a \rightarrow b)$ denotes the probability of transitioning from a to b. Let $g(b|a)$ denote our proposal distribution for a new sample b given the current sample a. Additionally, let $A(a \rightarrow b)$ denote the probability of accepting such a transition from a to b. Using our proportional function $f$ and the above definitions, the detailed balance condition can be written as such:
#
# \begin{equation}
# {f(a) \over NC})g(b|a)A(a \rightarrow b) = {f(b) \over NC}g(a|b)A(b \rightarrow a)
# \end{equation}
#
# The Metropolis algorithm derives acceptance probabilities that fulfill the above condition:
# \begin{equation}
# A(a \rightarrow b) = min(1, {f(b) \over f(a)})
# \end{equation}
#
# The proposal distribution needs to be symmetric for the above definition, in the code below we simply use a Gaussian distribution centered at the current sample with a small variance: $g(b|a) = \mathcal{N}(b|a, 0.05 \cdot I)$
#
# By defining the transition probabilities as described above, we achieve that our Markov Chain has the posterior distribution as its stationary distribution. This means once the chain has converged to the stationary distribution, the distribution of states over many iterations of the Markov Chain will resemble the posterior distribution. The visited states can be used as approximate samples from the posterior distribution. Since the Markov Chain needs to converge to the stationary distribution first, it is common practice to discard the first $m$ iterations of the Markov Chain, where $m$ is a large number. We use $m=400$ in the code below. This initial phase is commonly referred to as the "Burn-In" phase. For our toy example, we let the Markov Chain run for 500 iterations and discard the first 400 steps. Thus, we obtain 100 approximate samples from the posterior distribution.
#
# We observe that the last 100 samples are identical in some runs, which means none of the last 100 proposed samples was accepted. We assume that this might be due to our proposal distribution having too much variance, i.e. once we have converged to the value with the highest probability, it is very unlikely that it will propose another value with a probability that is not much smaller. We assume that this effect is amplified by the fact that our true posterior is a very narrow distribution, since we have observed $n=1000$ datapoints and only have to estimate 2 parameters (slope and intercept).
#
# Every computation of $f(w)$ involves computing $p(y|X, w)$. Since $y$ denotes the ground truth labels of the entire dataset, we actually need to compute $p(y|X, w) = \prod_{i=1}^n p(y_i|X, w)$. To avoid a numerical underflow when multiplying very small numbers repeatedly, we rewrite the expression to $exp(log(\prod_{i=1}^n p(y_i|X, w))) = exp(\sum_{i=1}^{n} log(p(y_i|X, w)))$. Still, taking the exponential of a large negative number can result in an underflow. Since we are never interested in the exact value of $f$ but rather the ratio of $f$ evaluated at two different locations $a$ and $b$, we can also avoid this evaluation:
#
# \begin{equation}
# {f(b) \over f(a)} = {\prod_{i=1}^n p(y_i|X, b) \over \prod_{i=1}^n p(y_i|X, a)} = {exp(\sum_{i=1}^{n} log(p(y_i|X, b))) \over exp(\sum_{i=1}^{n} log(p(y_i|X, a)))} = exp(\sum_{i=1}^{n} log(p(y_i|X, b)) - \sum_{i=1}^{n} log(p(y_i|X, a)))
# \end{equation}
#
# While this fixes the underflow issue, it can now happen that the second sum of logs is so much smaller than the first one, that the difference is a large positive number and an overflow happens when evaluating the $exp$ function. Therefore, we implement a last trick to account for this: We defined our acceptance probability as $A(a \rightarrow b) = min(1, {f(b) \over f(a)})$. The second expression inside the $min$ only needs to be evaluated if it is smaller than 1. To check, whether ${f(b) \over f(a)} < 1$, it is equivalent to check, whether $\sum_{i=1}^{n} log(p(y_i|X, b)) - \sum_{i=1}^{n} log(p(y_i|X, a)) < log({p(b) \over p(a)})$. In other words, we only need to evaluate the $exp$ expression if the difference between the sum of logs is negative or zero, thus we also avoid the overflow problem.

# %%
# With MCMC samples

current_sample = prior.rvs()
print("initial sample: " + str(current_sample))

# Loop over dataset to calculate dataset likelihood for a given sample
sum_logs = 0
for i in range(0, n_datapoints):
    train_features = np.stack((np.ones(1), np.array([train_points[i]])), axis=1)
    true_label = train_points[i] * slope + intercept
    pred_mean = train_features.dot(current_sample)
    pred_cov = noise_var
    predictive = univariate_normal(pred_mean, math.sqrt(pred_cov))

    sum_logs += math.log(predictive.pdf(true_label))
    
log_dataset_likelihood_current = sum_logs
print("log dataset_likelihood: " + str(log_dataset_likelihood_current))

posterior_samples = []

# Iterations of Markov Chain
for j in range(0, 500):
    
    proposal_sample = multivariate_normal(current_sample, np.identity(2) * 0.05).rvs()
    
    # Loop over dataset to calculate dataset likelihood for a given sample
    sum_logs = 0
    for i in range(0, n_datapoints):
        train_features = np.stack((np.ones(1), np.array([train_points[i]])), axis=1)
        true_label = train_points[i] * slope + intercept
        pred_mean = train_features.dot(proposal_sample)
        pred_cov = noise_var
        predictive = univariate_normal(pred_mean, math.sqrt(pred_cov))

        sum_logs += math.log(predictive.pdf(true_label))
        
    log_dataset_likelihood_proposal = sum_logs
    
    # Calculate the ratio of f_proposal and f_current. We avoid computing f directly, 
    # because it involves taking exp of a large negative number and will yield zero.
    difference = log_dataset_likelihood_proposal - log_dataset_likelihood_current
    prior_ratio = prior.pdf(proposal_sample) / prior.pdf(current_sample)
    
    if difference < math.log(prior_ratio):
        f_ratio = math.exp(log_dataset_likelihood_proposal - log_dataset_likelihood_current) * prior_ratio
    else: 
        f_ratio = 1
    
    acceptance_prob = min(1.0, f_ratio)
    r = random.uniform(0, 1)
    
    if r < acceptance_prob: # accept
        current_sample = proposal_sample
        log_dataset_likelihood_current = log_dataset_likelihood_proposal
    
    posterior_samples.append(current_sample)
    print(current_sample)
# Out:
# initial sample: [-1.46693832  2.48568354]
# log dataset_likelihood: -5407.404856457823
# [-1.10830296  2.63759784]
# [-1.10830296  2.63759784]
# [-0.75596116  2.64179952]
# [-0.46014587  2.51844121]
# [-0.87745115  2.34843644]
# [-0.49076772  2.01502083]
# [-0.49076772  2.01502083]
# [-0.60547225  1.91584639]
# [-0.58931685  1.79014307]
# [-0.58931685  1.79014307]
# [-0.58931685  1.79014307]
# [-0.77037921  1.51036   ]
# [-0.77037921  1.51036   ]
# [-0.77037921  1.51036   ]
# [-0.77037921  1.51036   ]
# [-0.77037921  1.51036   ]
# [-0.89250566  1.19407646]
# [-0.89250566  1.19407646]
# [-0.89250566  1.19407646]
# [-0.51667502  1.19357419]
# [-0.69958587  1.221082  ]
# [-0.82268901  1.08317696]
# [-0.72582611  0.72457215]
# [-0.72582611  0.72457215]
# [-0.73081445  0.80139328]
# [-0.73081445  0.80139328]
# [-0.73081445  0.80139328]
# [-0.73081445  0.80139328]
# [-0.73081445  0.80139328]
# [-0.73081445  0.80139328]
# [-0.73081445  0.80139328]
# [-0.73081445  0.80139328]
# [-0.73081445  0.80139328]
# [-0.73081445  0.80139328]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-683cbe15de6f> in <module>
#      34         predictive = univariate_normal(pred_mean, math.sqrt(pred_cov))
#      35
# ---> 36         sum_logs += math.log(predictive.pdf(true_label))
#      37
#      38     log_dataset_likelihood_proposal = sum_logs
#
# ~\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py in pdf(self, x)
#     451
#     452     def pdf(self, x):   # raises AttributeError in frozen discrete distribution
# --> 453         return self.dist.pdf(x, *self.args, **self.kwds)
#     454
#     455     def logpdf(self, x):
#
# ~\anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py in pdf(self, x, *args, **kwds)
#    1911             goodargs = argsreduce(cond, *((x,)+args+(scale,)))
#    1912             scale, goodargs = goodargs[-1], goodargs[:-1]
# -> 1913             place(output, cond, self._pdf(*goodargs) / scale)
#    1914         if output.ndim == 0:
#    1915             return output[()]
#
# KeyboardInterrupt:

# %%
ML_estimate = harmonic_mean_estimator(posterior_samples[-100:])
print("Estimated Log Marginal Likelihood on the training set: " + str(math.log(ML_estimate)))
# Out:
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.72711932  0.90185507]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# current sample: [-0.69147792  0.92226409]
# Estimated Log Marginal Likelihood on the training set: -228.58664948938338

# %% [markdown]
# # Annealed Importance sampling
# Annealed importance sampling combines the concepts of MCMC sampling and importance weights. It gives us a stochastic lower bound of the marginal likelihood. This means with infinite samples, the probability of overestimating the true ML goes down to zero. The idea of annealed importance sampling is using a series of intermediate distributions to bridge between prior and posterior distribution, because it is inefficient to use a single importance sampling computation between two very dissimilar distributions.
# This algorithm takes as input a sequence of T distributions $p_0$,...,$p_T$, with $p_t(x) = f_t(x) / Z_t$, where $p_T$ is the target distribution (posterior $p(\omega|y, x)$) and $p_0$ is the proposal distribution(prior $p(\omega)$) and the intermediate distributions are taken to be geometric averages of the initial and target distribution: $f_t(\omega) = f_0(\omega)^{1-\beta_t}f_T(\omega)^{\beta_t}$, where $\beta$ are monotonically increasing parameters with $\beta_0 = 0$ and $\beta_T = 1$, in our case we take $\beta_t = t/T$ and we can represent intermediate distribution with prior and posterior
# \begin{equation}
# f_t(\omega) = f_0(\omega)^{1-\beta_t}f_T(\omega)^{\beta_t}
# \end{equation}
# \begin{equation}
# f_0(\omega) = p(\omega)
# \end{equation}
# \begin{equation}
# f_T(\omega) = p(y|\omega,x)p(\omega)
# \end{equation}
# When we insert the last two equations into the first one, we get the following representation:
# \begin{equation}
# f_t(\omega) = p(\omega)^{1-\beta_t}(p(y|\omega,x)p(\omega))^{\beta_t} \\
# ==> f_t(\omega) = p(\omega)p(y|\omega,x)^{\beta_t}
# \end{equation}
#
#
# ## Explanation of the Algorithm
# After defining these intermediate distributions, we would like to introduce the algorithm itself.
# This algorithm can be divided into an outer loop and and inner loop. The outer loop calculates the Monte Carlo estimator of the expectation of parameter x and the inner loop is an MCMC process designed to tranform a sample from the prior to one of the posterior.
# ### Inner loop
# We introduce the inner loop first. Since we have several intermediate distributions, we need to do MCMC between them in order to calculate the final weight as the product of weights for each MCMC transition. The weight for each MCMC transition is defined as below:
# \begin{equation}
# w_t^{(k)} = \frac {f_t(x_{t-1})} {f_{t-1}(x_{t-1})} = \frac {p(w)p(y|\omega, x)^{\beta_t}} {p(\omega)p(y|\omega, x)^{\beta_{t-1}}} = p(y|\omega, x)^{\beta_t-\beta_{t-1}}
# \end{equation}
# Since we have $\beta_t = \frac t T$, we can equivalently write $w_t^{(k)} = p(y|\omega, x)^{1/T}$ and in log space it becomes
# \begin{equation}
# log(w_t^{(k)}) = 1/T * log(p(y|\omega, x))
# \end{equation}
# After we have the weight of the MCMC step, we need to transition to the next state based on the current state, which we use the afore mentioned Metropolis algorithm for. The transition probability is defined as
# \begin{equation}
# \frac{f_t(x_p)}{f_t(x_c)} = \frac{p(\omega_p)p(y|\omega_p, x)^{\beta_t}}{p(\omega_c)p(y|\omega_c, x)^{\beta_t}}
# \end{equation}
# The proposal for the next state will be sampled from a normal distribution, whose mean is the current sample and whose standard derivation is fixed as a hyperparameter (current setting is an identity matrix multiplied with 0.05).
# When the inner loop is finished, we can obtain a cumulated weight for the sample $\omega_k$.
# \begin{equation}
# \omega_k = \prod_{t = 2}^{T} \frac {f_t(x_{t-1})} {f_{t-1}(x_{t-1})}  ==> log(\omega_k) = \sum_{t=2}^{T} log(\frac {f_t(x_{t-1})} {f_{t-1}(x_{t-1})} ) ==> log(\omega_k) = \sum_{t=2}^{T}1/T * log(p(y|\omega, x))
# \end{equation}
# ### Outer loop
# The outer loop is rather simple, it samples K times from the prior and then does the inner loop. Afer we have multiple weights, we take the average of these weights to be our estimator.

# %%
# Annealed Importance Sampling

# K and T are hyperparameters, K for MC estimate, T is number of intermediate distributions
def annealed_importance_sampling(prior, K, T):
    # Outer loop for MC estimate of E[w]
    omega_list = []
    for k in range(0, K): 
        x = prior.rvs()
        log_omega = 0
        
        for t in range(1, T):
            #print("Current sample: " + str(x) + " chain " + str(k) + ", sample " + str(t))
            log_omega = log_omega + evaluate_intermediate_ratio(x, T)
            x = transition_sample(prior, x, t, T)

        print("Finished simulating chain " + str(k) + ", omega sample is: " + str(math.exp(log_omega)) + ", log omega: " + str(log_omega))
        omega_list.append(math.exp(log_omega))
        
    Z_estimator = sum(omega_list) / len(omega_list)
    print(omega_list)
    print("ML estimate: " + str(Z_estimator))
    print("Log ML estimate: " + str(math.log(Z_estimator)))

def evaluate_intermediate_ratio(x, T):
    log_dataset_likelihood = get_log_dataset_likelihood_vec(x)
    intermediate_ratio = (1.0 / T) * log_dataset_likelihood
    #print("log dataset likelihood: " + str(log_dataset_likelihood) + ", intermediate_ratio: " + str(intermediate_ratio))
    return intermediate_ratio


def transition_sample(prior, current_sample, t, T, n_steps=10):
    log_dataset_likelihood_current = get_log_dataset_likelihood_vec(current_sample)
    for i in range(0, n_steps):
        proposal_sample = multivariate_normal(current_sample, np.identity(2) * 0.05).rvs()
        log_dataset_likelihood_proposal = get_log_dataset_likelihood_vec(proposal_sample)
        beta_t = float(t) / T
    
        log_prior_ratio = math.log(prior.pdf(proposal_sample)) - math.log(prior.pdf(current_sample))
        log_f_ratio = log_prior_ratio + beta_t * (log_dataset_likelihood_proposal - log_dataset_likelihood_current)
    
        # We only need to evaluate f_ratio if its log is smaller than 0, otherwise f_ratio is larger than 1
        if(log_f_ratio < 0):
            f_ratio = math.exp(log_f_ratio)
        else:
            f_ratio = 1
    
        acceptance_prob = f_ratio
        r = random.uniform(0, 1)

        if r < acceptance_prob: # accept
            current_sample = proposal_sample
            log_dataset_likelihood_current = log_dataset_likelihood_proposal
    
    return current_sample

# This for-loop should be removed/vectorized!!
def get_log_dataset_likelihood(parameter_val):
    # Loop over dataset to calculate dataset likelihood for a given sample
    sum_logs = 0
    for i in range(0, n_datapoints):
        
        train_features = np.stack((np.ones(1), np.array([train_points[i]])), axis=1)
        true_label = train_points[i] * slope + intercept
        pred_mean = train_features.dot(parameter_val)
        pred_cov = noise_var
        predictive = univariate_normal(pred_mean, math.sqrt(pred_cov))

        sum_logs += math.log(predictive.pdf(true_label))

    log_dataset_likelihood = sum_logs
    print("log_dataset_likelihood: " + str(log_dataset_likelihood))
    return log_dataset_likelihood

def get_log_dataset_likelihood_vec(parameter_val):
    ones = np.ones(n_datapoints)
    train_features = np.stack([ones, train_points], axis=1)
    true_labels = train_points * slope + intercept
    
    pred_means = train_features.dot(parameter_val)
    pred_cov = noise_var
    predictive = univariate_normal(pred_means, math.sqrt(pred_cov))
    
    log_lhds = np.log(predictive.pdf(true_labels))
    return np.sum(log_lhds)

# %%
import time

start_time = time.time()
annealed_importance_sampling(prior, 100, 1000)   
end_time = time.time()
print("Running the algorithm took " + str(end_time - start_time) + " seconds")
# Out:
# Finished simulating chain 0, omega sample is: 1.0430230583504228e-118, log omega: -271.6629176898046
# Finished simulating chain 1, omega sample is: 1.7589067154800198e-116, log omega: -266.53517835566055
# Finished simulating chain 2, omega sample is: 2.3207169256598825e-109, log omega: -250.13989897872852
# Finished simulating chain 3, omega sample is: 5.351281853132564e-120, log omega: -274.6328750283604
# Finished simulating chain 4, omega sample is: 1.8045266128441122e-126, log omega: -289.5354234242145
# Finished simulating chain 5, omega sample is: 1.85649076693129e-111, log omega: -254.96825730109038
# Finished simulating chain 6, omega sample is: 3.806972015452218e-107, log omega: -245.03977082380325
# Finished simulating chain 7, omega sample is: 2.7471735656210595e-160, log omega: -367.4030422902312
# Finished simulating chain 8, omega sample is: 1.5315356001535822e-104, log omega: -239.04257877907548
# Finished simulating chain 9, omega sample is: 5.817195103016911e-114, log omega: -260.73388239681117
# Finished simulating chain 10, omega sample is: 4.172570898902464e-106, log omega: -242.6454874890115
# Finished simulating chain 11, omega sample is: 1.403774119880609e-103, log omega: -236.8271001690021
# Finished simulating chain 12, omega sample is: 3.6122359624198646e-137, log omega: -314.1698307794045
# Finished simulating chain 13, omega sample is: 1.3692938263211377e-138, log omega: -317.44244768147104
# Finished simulating chain 14, omega sample is: 1.1994907466216334e-123, log omega: -283.0360693493627
# Finished simulating chain 15, omega sample is: 1.2480763214218545e-109, log omega: -250.76017171328817
# Finished simulating chain 16, omega sample is: 2.7517891514185027e-106, log omega: -243.0617685567233
# Finished simulating chain 17, omega sample is: 1.6954227159679884e-101, log omega: -232.0331622927071
# Finished simulating chain 18, omega sample is: 1.368232723133462e-117, log omega: -269.088935956322
# Finished simulating chain 19, omega sample is: 3.1906273683829675e-129, log omega: -295.8732594315669
# Finished simulating chain 20, omega sample is: 3.2197823261379656e-108, log omega: -247.5098762866639
# Finished simulating chain 21, omega sample is: 7.254764948644488e-139, log omega: -318.07766943889385
# Finished simulating chain 22, omega sample is: 7.579219267558883e-129, log omega: -295.00806680088516
# Finished simulating chain 23, omega sample is: 5.6301740112099154e-117, log omega: -267.6743155307768
# Finished simulating chain 24, omega sample is: 3.324091229229866e-136, log omega: -311.95037632495695
# Finished simulating chain 25, omega sample is: 6.278394526107074e-169, log omega: -387.2997664169064
# Finished simulating chain 26, omega sample is: 2.80231409805645e-104, log omega: -238.43840413194098
# Finished simulating chain 27, omega sample is: 5.540400081829093e-102, log omega: -233.15161277030433
# Finished simulating chain 28, omega sample is: 2.1051583107601334e-105, log omega: -241.02704409305642
# Finished simulating chain 29, omega sample is: 2.612286313384218e-120, log omega: -275.3499853392598
# Finished simulating chain 30, omega sample is: 3.2436556617145306e-139, log omega: -318.882626941757
# Finished simulating chain 31, omega sample is: 3.757568908124503e-101, log omega: -231.23732221109955
# Finished simulating chain 32, omega sample is: 6.175368748990553e-124, log omega: -283.69998293409486
# Finished simulating chain 33, omega sample is: 1.1671804910862167e-104, log omega: -239.31425866757928
# Finished simulating chain 34, omega sample is: 8.744430369132267e-135, log omega: -308.6805705857394
# Finished simulating chain 35, omega sample is: 1.2854556825005905e-101, log omega: -232.3099811201811
# Finished simulating chain 36, omega sample is: 2.2242662743479344e-101, log omega: -231.76166729550263
# Finished simulating chain 37, omega sample is: 1.3756561083737179e-139, log omega: -319.74039713913675
# Finished simulating chain 38, omega sample is: 2.5439736885390283e-112, log omega: -256.95580311246414
# Finished simulating chain 39, omega sample is: 3.78469230766114e-120, log omega: -274.9792465682603
# Finished simulating chain 40, omega sample is: 8.219765284030615e-132, log omega: -301.8346906208078
# Finished simulating chain 41, omega sample is: 7.808535433891853e-110, log omega: -251.22914280754802
# Finished simulating chain 42, omega sample is: 3.67427470147295e-104, log omega: -238.16749391833744
# Finished simulating chain 43, omega sample is: 1.354945029324304e-128, log omega: -294.42713101849347
# Finished simulating chain 44, omega sample is: 7.08172846483222e-120, log omega: -274.3526931479247
# Finished simulating chain 45, omega sample is: 1.7057331131823733e-117, log omega: -268.868460883576
# Finished simulating chain 46, omega sample is: 1.2893122167697612e-107, log omega: -246.12249603946722
# Finished simulating chain 47, omega sample is: 5.904830008625885e-109, log omega: -249.20600447481698
# Finished simulating chain 48, omega sample is: 1.3747512140878815e-110, log omega: -252.96608744980605
# Finished simulating chain 49, omega sample is: 4.231458182979579e-107, log omega: -244.93405829259976
# Finished simulating chain 50, omega sample is: 1.3011953638918002e-101, log omega: -232.2978110397361
# Finished simulating chain 51, omega sample is: 8.268999593008593e-102, log omega: -232.75116595187157
# Finished simulating chain 52, omega sample is: 8.90138903764168e-131, log omega: -299.45243984601467
# Finished simulating chain 53, omega sample is: 9.768995858503311e-104, log omega: -237.18963598865278
# Finished simulating chain 54, omega sample is: 3.233582396282841e-113, log omega: -259.0185248846744
# Finished simulating chain 55, omega sample is: 1.521468190054933e-115, log omega: -264.3776099111425
# Finished simulating chain 56, omega sample is: 1.1310611397492207e-143, log omega: -329.14651204434193
# Finished simulating chain 57, omega sample is: 7.630439939568273e-104, log omega: -237.43670416856335
# Finished simulating chain 58, omega sample is: 1.9340486364613572e-128, log omega: -294.07127635840436
# Finished simulating chain 59, omega sample is: 7.626573492955722e-102, log omega: -232.83204082445653
# Finished simulating chain 60, omega sample is: 4.422973946463751e-110, log omega: -251.79754792094334
# Finished simulating chain 61, omega sample is: 1.205797270253942e-111, log omega: -255.39980433911492
# Finished simulating chain 62, omega sample is: 1.2864868463336978e-113, log omega: -259.9402003800209
# Finished simulating chain 63, omega sample is: 4.1609790068731717e-165, log omega: -378.5007899592414
# Finished simulating chain 64, omega sample is: 2.172927502206057e-109, log omega: -250.20569979863092
# Finished simulating chain 65, omega sample is: 7.835999137708824e-105, log omega: -239.71270637433477
# Finished simulating chain 66, omega sample is: 1.2612965393585757e-129, log omega: -296.80133680483465
# Finished simulating chain 67, omega sample is: 1.0167118387616018e-226, log omega: -520.3676572841214
# Finished simulating chain 68, omega sample is: 9.476906704675986e-115, log omega: -262.54842772826987
# Finished simulating chain 69, omega sample is: 4.621355238943099e-107, log omega: -244.84591694652295
# Finished simulating chain 70, omega sample is: 1.253995231241754e-105, log omega: -241.54510012500882
# Finished simulating chain 71, omega sample is: 7.78675478457858e-141, log omega: -322.6120739264199
# Finished simulating chain 72, omega sample is: 4.334774642505428e-113, log omega: -258.72544588502717
# Finished simulating chain 73, omega sample is: 1.8638994748064542e-124, log omega: -284.8978807462774
# Finished simulating chain 74, omega sample is: 1.7753007697357093e-111, log omega: -255.0129754660279
# Finished simulating chain 75, omega sample is: 2.128476445069539e-107, log omega: -245.62119851058412
# Finished simulating chain 76, omega sample is: 1.3477904555076954e-133, log omega: -305.94535081623775
# Finished simulating chain 77, omega sample is: 1.3445663912845834e-108, log omega: -248.38311846794258
# Finished simulating chain 78, omega sample is: 1.2483982139974857e-111, log omega: -255.36508402155883
# Finished simulating chain 79, omega sample is: 1.2455057778669662e-102, log omega: -234.64413779068937
# Finished simulating chain 80, omega sample is: 3.865848517163448e-108, log omega: -247.3270088466899
# Finished simulating chain 81, omega sample is: 6.299061001195278e-151, log omega: -345.8499484672414
# Finished simulating chain 82, omega sample is: 2.108862811707804e-115, log omega: -264.05113684391125
# Finished simulating chain 83, omega sample is: 1.0529639035876557e-104, log omega: -239.41724071841034
# Finished simulating chain 84, omega sample is: 3.335177976444416e-109, log omega: -249.77724909215712
# Finished simulating chain 85, omega sample is: 7.595159131281182e-108, log omega: -246.65167895541794
# Finished simulating chain 86, omega sample is: 4.425296431936258e-102, log omega: -233.37634221890843
# Finished simulating chain 87, omega sample is: 1.6974635894080809e-118, log omega: -271.1759058426154
# Finished simulating chain 88, omega sample is: 2.438636580813338e-101, log omega: -231.6696552876235
# Finished simulating chain 89, omega sample is: 1.6455406937749117e-109, log omega: -250.48370611691524
# Finished simulating chain 90, omega sample is: 2.946600836409464e-136, log omega: -312.07092040004335
# Finished simulating chain 91, omega sample is: 1.098416560414295e-127, log omega: -292.3344371580338
# Finished simulating chain 92, omega sample is: 5.09578919989144e-131, log omega: -300.0102326306041
# Finished simulating chain 93, omega sample is: 5.272264144304379e-179, log omega: -410.5002717467447
# Finished simulating chain 94, omega sample is: 6.568427368088987e-238, log omega: -546.1329776943265
# Finished simulating chain 95, omega sample is: 4.628359146046432e-118, log omega: -270.17283856411467
# Finished simulating chain 96, omega sample is: 2.5249826662381633e-120, log omega: -275.3839769614379
# Finished simulating chain 97, omega sample is: 3.3220860301092354e-112, log omega: -256.6889375073945
# Finished simulating chain 98, omega sample is: 5.872002046079541e-106, log omega: -242.3038242176099
# Finished simulating chain 99, omega sample is: 7.755290874961462e-107, log omega: -244.32822964638345
# [1.0430230583504228e-118, 1.7589067154800198e-116, 2.3207169256598825e-109, 5.351281853132564e-120, 1.8045266128441122e-126, 1.85649076693129e-111, 3.806972015452218e-107, 2.7471735656210595e-160, 1.5315356001535822e-104, 5.817195103016911e-114, 4.172570898902464e-106, 1.403774119880609e-103, 3.6122359624198646e-137, 1.3692938263211377e-138, 1.1994907466216334e-123, 1.2480763214218545e-109, 2.7517891514185027e-106, 1.6954227159679884e-101, 1.368232723133462e-117, 3.1906273683829675e-129, 3.2197823261379656e-108, 7.254764948644488e-139, 7.579219267558883e-129, 5.6301740112099154e-117, 3.324091229229866e-136, 6.278394526107074e-169, 2.80231409805645e-104, 5.540400081829093e-102, 2.1051583107601334e-105, 2.612286313384218e-120, 3.2436556617145306e-139, 3.757568908124503e-101, 6.175368748990553e-124, 1.1671804910862167e-104, 8.744430369132267e-135, 1.2854556825005905e-101, 2.2242662743479344e-101, 1.3756561083737179e-139, 2.5439736885390283e-112, 3.78469230766114e-120, 8.219765284030615e-132, 7.808535433891853e-110, 3.67427470147295e-104, 1.354945029324304e-128, 7.08172846483222e-120, 1.7057331131823733e-117, 1.2893122167697612e-107, 5.904830008625885e-109, 1.3747512140878815e-110, 4.231458182979579e-107, 1.3011953638918002e-101, 8.268999593008593e-102, 8.90138903764168e-131, 9.768995858503311e-104, 3.233582396282841e-113, 1.521468190054933e-115, 1.1310611397492207e-143, 7.630439939568273e-104, 1.9340486364613572e-128, 7.626573492955722e-102, 4.422973946463751e-110, 1.205797270253942e-111, 1.2864868463336978e-113, 4.1609790068731717e-165, 2.172927502206057e-109, 7.835999137708824e-105, 1.2612965393585757e-129, 1.0167118387616018e-226, 9.476906704675986e-115, 4.621355238943099e-107, 1.253995231241754e-105, 7.78675478457858e-141, 4.334774642505428e-113, 1.8638994748064542e-124, 1.7753007697357093e-111, 2.128476445069539e-107, 1.3477904555076954e-133, 1.3445663912845834e-108, 1.2483982139974857e-111, 1.2455057778669662e-102, 3.865848517163448e-108, 6.299061001195278e-151, 2.108862811707804e-115, 1.0529639035876557e-104, 3.335177976444416e-109, 7.595159131281182e-108, 4.425296431936258e-102, 1.6974635894080809e-118, 2.438636580813338e-101, 1.6455406937749117e-109, 2.946600836409464e-136, 1.098416560414295e-127, 5.09578919989144e-131, 5.272264144304379e-179, 6.568427368088987e-238, 4.628359146046432e-118, 2.5249826662381633e-120, 3.3220860301092354e-112, 5.872002046079541e-106, 7.755290874961462e-107]
# ML estimate: 1.5456161604042375e-102
# Log ML estimate: -234.42825684522313
# Running the algorithm took 1038.0398395061493 seconds

# %%
import math
# Mistake in above run, omega list average was calculated wrong. Recalculating from printed omega values:

omega_list_reconstructed = [3.6657233556458394e-128, 1.426388862681818e-141, 0.0, 2.818330322776316e-127, 3.4222148529809e-218, 2.6033340302506115e-127, 4.932790078584945e-105, 6.648654311391227e-249, 1.097418509842091e-161, 1.0455006198670662e-118]
print(len(omega_list_reconstructed))
print(sum(omega_list_reconstructed))
print(max(omega_list_reconstructed))

Z_estimator = sum(omega_list_reconstructed) / len(omega_list_reconstructed)

print("ML estimate: " + str(Z_estimator))
print("Log ML estimate: " + str(math.log(Z_estimator)))
# Out:
# 10
# 4.932790078585049e-105
# 4.932790078584945e-105
# ML estimate: 4.932790078585049e-106
# Log ML estimate: -242.4781150905362

# %%
# Reverse AIS

# f_1 is now the unnormalized posterior (likelihood times prior), and f_T is the prior distribution (inverse to regular AIS)
def reversed_ais(posterior_samples, T):
    # Outer loop for MC estimate of E[w]
    omega_list = []
    for k in range(0, len(posterior_samples)): 
        x = posterior_samples[k]
        log_omega = 0
        
        for t in range(1, T + 1):
            print("Current sample: " + str(x) + " chain " + str(k) + ", sample " + str(t))

            log_omega = log_omega + evaluate_intermediate_ratio(x, T)
            x = transition_sample_inverse(prior, x, t, T)

        print("Finished simulating chain, omega sample is: " + str(math.exp(log_omega)) + ", log omega: " + str(log_omega))
        omega_list.append(math.exp(log_omega))
        
    Z_estimator = sum(omega_list) / len(omega_list)
    print(omega_list)
    print("ML estimate: " + str(Z_estimator))
    print("Log ML estimate: " + str(math.log(Z_estimator)))
    
def transition_sample_inverse(prior, current_sample, t, T, n_steps=10):
    log_dataset_likelihood_current = get_log_dataset_likelihood(current_sample)
    for i in range(0, n_steps):
        proposal_sample = multivariate_normal(current_sample, np.identity(2) * 0.05).rvs()
        log_dataset_likelihood_proposal = get_log_dataset_likelihood(proposal_sample)
        beta_t = float(t) / T
    
        log_prior_ratio = math.log(prior.pdf(proposal_sample)) - math.log(prior.pdf(current_sample))
        # Only thing changed from the forward chain is (1 - beta_t) instead of beta_t
        log_f_ratio = log_prior_ratio + (1 - beta_t) * (log_dataset_likelihood_proposal - log_dataset_likelihood_current)
    
        # We only need to evaluate f_ratio if its log is smaller than 0, otherwise f_ratio is larger than 1
        if(log_f_ratio < 0):
            f_ratio = math.exp(log_f_ratio)
        else:
            f_ratio = 1
            
        acceptance_prob = f_ratio
        r = random.uniform(0, 1)

        if r < acceptance_prob: # accept
            current_sample = proposal_sample
            log_dataset_likelihood_current = log_dataset_likelihood_proposal
    
    return current_sample

# %%
K = 10
true_samples = posterior.rvs(size=K)

reversed_ais(true_samples, 100)
# Out:
# Current sample: [-0.6759839   0.86212181] chain 0, sample 1
# log dataset likelihood: -229.25557675334124, intermediate_ratio: -2.2925557675334125
# Current sample: [-0.6759839   0.86212181] chain 0, sample 2
# log dataset likelihood: -229.25557675334124, intermediate_ratio: -2.2925557675334125
# Current sample: [-0.6759839   0.86212181] chain 0, sample 3
# log dataset likelihood: -229.25557675334124, intermediate_ratio: -2.2925557675334125
# Current sample: [-0.6759839   0.86212181] chain 0, sample 4
# log dataset likelihood: -229.25557675334124, intermediate_ratio: -2.2925557675334125
# Current sample: [-0.6759839   0.86212181] chain 0, sample 5
# log dataset likelihood: -229.25557675334124, intermediate_ratio: -2.2925557675334125
# Current sample: [-0.6759839   0.86212181] chain 0, sample 6
# log dataset likelihood: -229.25557675334124, intermediate_ratio: -2.2925557675334125
# Current sample: [-0.6759839   0.86212181] chain 0, sample 7
# log dataset likelihood: -229.25557675334124, intermediate_ratio: -2.2925557675334125
# Current sample: [-0.70144749  0.8654835 ] chain 0, sample 8
# log dataset likelihood: -227.62011445000334, intermediate_ratio: -2.2762011445000336
# Current sample: [-0.70144749  0.8654835 ] chain 0, sample 9
# log dataset likelihood: -227.62011445000334, intermediate_ratio: -2.2762011445000336
# Current sample: [-0.70144749  0.8654835 ] chain 0, sample 10
# log dataset likelihood: -227.62011445000334, intermediate_ratio: -2.2762011445000336
# Current sample: [-0.70144749  0.8654835 ] chain 0, sample 11
# log dataset likelihood: -227.62011445000334, intermediate_ratio: -2.2762011445000336
# Current sample: [-0.70144749  0.8654835 ] chain 0, sample 12
# log dataset likelihood: -227.62011445000334, intermediate_ratio: -2.2762011445000336
# Current sample: [-0.70144749  0.8654835 ] chain 0, sample 13
# log dataset likelihood: -227.62011445000334, intermediate_ratio: -2.2762011445000336
# Current sample: [-0.70144749  0.8654835 ] chain 0, sample 14
# log dataset likelihood: -227.62011445000334, intermediate_ratio: -2.2762011445000336
# Current sample: [-0.70144749  0.8654835 ] chain 0, sample 15
# log dataset likelihood: -227.62011445000334, intermediate_ratio: -2.2762011445000336
# Current sample: [-0.66631916  0.88084097] chain 0, sample 16
# log dataset likelihood: -228.69955137123543, intermediate_ratio: -2.2869955137123545
# Current sample: [-0.66631916  0.88084097] chain 0, sample 17
# log dataset likelihood: -228.69955137123543, intermediate_ratio: -2.2869955137123545
# Current sample: [-0.66631916  0.88084097] chain 0, sample 18
# log dataset likelihood: -228.69955137123543, intermediate_ratio: -2.2869955137123545
# Current sample: [-0.66631916  0.88084097] chain 0, sample 19
# log dataset likelihood: -228.69955137123543, intermediate_ratio: -2.2869955137123545
# Current sample: [-0.66555254  0.95297397] chain 0, sample 20
# log dataset likelihood: -232.26266930415278, intermediate_ratio: -2.322626693041528
# Current sample: [-0.66555254  0.95297397] chain 0, sample 21
# log dataset likelihood: -232.26266930415278, intermediate_ratio: -2.322626693041528
# Current sample: [-0.66555254  0.95297397] chain 0, sample 22
# log dataset likelihood: -232.26266930415278, intermediate_ratio: -2.322626693041528
# Current sample: [-0.66555254  0.95297397] chain 0, sample 23
# log dataset likelihood: -232.26266930415278, intermediate_ratio: -2.322626693041528
# Current sample: [-0.66555254  0.95297397] chain 0, sample 24
# log dataset likelihood: -232.26266930415278, intermediate_ratio: -2.322626693041528
# Current sample: [-0.66555254  0.95297397] chain 0, sample 25
# log dataset likelihood: -232.26266930415278, intermediate_ratio: -2.322626693041528
# Current sample: [-0.68852977  0.88975222] chain 0, sample 26
# log dataset likelihood: -226.22957354211556, intermediate_ratio: -2.2622957354211555
# Current sample: [-0.68852977  0.88975222] chain 0, sample 27
# log dataset likelihood: -226.22957354211556, intermediate_ratio: -2.2622957354211555
# Current sample: [-0.68852977  0.88975222] chain 0, sample 28
# log dataset likelihood: -226.22957354211556, intermediate_ratio: -2.2622957354211555
# Current sample: [-0.68852977  0.88975222] chain 0, sample 29
# log dataset likelihood: -226.22957354211556, intermediate_ratio: -2.2622957354211555
# Current sample: [-0.68852977  0.88975222] chain 0, sample 30
# log dataset likelihood: -226.22957354211556, intermediate_ratio: -2.2622957354211555
# Current sample: [-0.68852977  0.88975222] chain 0, sample 31
# log dataset likelihood: -226.22957354211556, intermediate_ratio: -2.2622957354211555
# Current sample: [-0.68852977  0.88975222] chain 0, sample 32
# log dataset likelihood: -226.22957354211556, intermediate_ratio: -2.2622957354211555
# Current sample: [-0.68852977  0.88975222] chain 0, sample 33
# log dataset likelihood: -226.22957354211556, intermediate_ratio: -2.2622957354211555
# Current sample: [-0.68852977  0.88975222] chain 0, sample 34
# log dataset likelihood: -226.22957354211556, intermediate_ratio: -2.2622957354211555
# Current sample: [-0.68852977  0.88975222] chain 0, sample 35
# log dataset likelihood: -226.22957354211556, intermediate_ratio: -2.2622957354211555
# Current sample: [-0.68852977  0.88975222] chain 0, sample 36
# log dataset likelihood: -226.22957354211556, intermediate_ratio: -2.2622957354211555
# Current sample: [-0.68852977  0.88975222] chain 0, sample 37
# log dataset likelihood: -226.22957354211556, intermediate_ratio: -2.2622957354211555
# Current sample: [-0.68852977  0.88975222] chain 0, sample 38
# log dataset likelihood: -226.22957354211556, intermediate_ratio: -2.2622957354211555
# Current sample: [-0.68852977  0.88975222] chain 0, sample 39
# log dataset likelihood: -226.22957354211556, intermediate_ratio: -2.2622957354211555
# Current sample: [-0.68852977  0.88975222] chain 0, sample 40
# log dataset likelihood: -226.22957354211556, intermediate_ratio: -2.2622957354211555
# Current sample: [-0.68852977  0.88975222] chain 0, sample 41
# log dataset likelihood: -226.22957354211556, intermediate_ratio: -2.2622957354211555
# Current sample: [-0.68852977  0.88975222] chain 0, sample 42
# log dataset likelihood: -226.22957354211556, intermediate_ratio: -2.2622957354211555
# Current sample: [-0.65632348  0.89380363] chain 0, sample 43
# log dataset likelihood: -229.6972619406154, intermediate_ratio: -2.296972619406154
# Current sample: [-0.66496864  0.96163855] chain 0, sample 44
# log dataset likelihood: -233.83042141436488, intermediate_ratio: -2.338304214143649
# Current sample: [-0.63602349  0.90741022] chain 0, sample 45
# log dataset likelihood: -234.00627348782797, intermediate_ratio: -2.3400627348782796
# Current sample: [-0.65794391  0.88928225] chain 0, sample 46
# log dataset likelihood: -229.5579672103753, intermediate_ratio: -2.295579672103753
# Current sample: [-0.65794391  0.88928225] chain 0, sample 47
# log dataset likelihood: -229.5579672103753, intermediate_ratio: -2.295579672103753
# Current sample: [-0.65794391  0.88928225] chain 0, sample 48
# log dataset likelihood: -229.5579672103753, intermediate_ratio: -2.295579672103753
# Current sample: [-0.65794391  0.88928225] chain 0, sample 49
# log dataset likelihood: -229.5579672103753, intermediate_ratio: -2.295579672103753
# Current sample: [-0.72844225  0.94105143] chain 0, sample 50
# log dataset likelihood: -230.13491186094413, intermediate_ratio: -2.3013491186094415
# Current sample: [-0.72844225  0.94105143] chain 0, sample 51
# log dataset likelihood: -230.13491186094413, intermediate_ratio: -2.3013491186094415
# Current sample: [-0.72844225  0.94105143] chain 0, sample 52
# log dataset likelihood: -230.13491186094413, intermediate_ratio: -2.3013491186094415
# Current sample: [-0.72844225  0.94105143] chain 0, sample 53
# log dataset likelihood: -230.13491186094413, intermediate_ratio: -2.3013491186094415
# Current sample: [-0.72844225  0.94105143] chain 0, sample 54
# log dataset likelihood: -230.13491186094413, intermediate_ratio: -2.3013491186094415
# Current sample: [-0.72844225  0.94105143] chain 0, sample 55
# log dataset likelihood: -230.13491186094413, intermediate_ratio: -2.3013491186094415
# Current sample: [-0.73195019  0.88042945] chain 0, sample 56
# log dataset likelihood: -228.34831181885045, intermediate_ratio: -2.2834831181885047
# Current sample: [-0.73195019  0.88042945] chain 0, sample 57
# log dataset likelihood: -228.34831181885045, intermediate_ratio: -2.2834831181885047
# Current sample: [-0.73195019  0.88042945] chain 0, sample 58
# log dataset likelihood: -228.34831181885045, intermediate_ratio: -2.2834831181885047
# Current sample: [-0.73195019  0.88042945] chain 0, sample 59
# log dataset likelihood: -228.34831181885045, intermediate_ratio: -2.2834831181885047
# Current sample: [-0.73195019  0.88042945] chain 0, sample 60
# log dataset likelihood: -228.34831181885045, intermediate_ratio: -2.2834831181885047
# Current sample: [-0.73195019  0.88042945] chain 0, sample 61
# log dataset likelihood: -228.34831181885045, intermediate_ratio: -2.2834831181885047
# Current sample: [-0.73195019  0.88042945] chain 0, sample 62
# log dataset likelihood: -228.34831181885045, intermediate_ratio: -2.2834831181885047
# Current sample: [-0.73195019  0.88042945] chain 0, sample 63
# log dataset likelihood: -228.34831181885045, intermediate_ratio: -2.2834831181885047
# Current sample: [-0.73195019  0.88042945] chain 0, sample 64
# log dataset likelihood: -228.34831181885045, intermediate_ratio: -2.2834831181885047
# Current sample: [-0.73195019  0.88042945] chain 0, sample 65
# log dataset likelihood: -228.34831181885045, intermediate_ratio: -2.2834831181885047
# Current sample: [-0.73195019  0.88042945] chain 0, sample 66
# log dataset likelihood: -228.34831181885045, intermediate_ratio: -2.2834831181885047
# Current sample: [-0.73195019  0.88042945] chain 0, sample 67
# log dataset likelihood: -228.34831181885045, intermediate_ratio: -2.2834831181885047
# Current sample: [-0.73195019  0.88042945] chain 0, sample 68
# log dataset likelihood: -228.34831181885045, intermediate_ratio: -2.2834831181885047
# Current sample: [-0.72230705  0.94794343] chain 0, sample 69
# log dataset likelihood: -230.4430618731105, intermediate_ratio: -2.304430618731105
# Current sample: [-0.74590314  0.88800952] chain 0, sample 70
# log dataset likelihood: -230.16208231908283, intermediate_ratio: -2.301620823190828
# Current sample: [-0.68740196  0.94304312] chain 0, sample 71
# log dataset likelihood: -228.8918181824156, intermediate_ratio: -2.288918181824156
# Current sample: [-0.68740196  0.94304312] chain 0, sample 72
# log dataset likelihood: -228.8918181824156, intermediate_ratio: -2.288918181824156
# Current sample: [-0.68740196  0.94304312] chain 0, sample 73
# log dataset likelihood: -228.8918181824156, intermediate_ratio: -2.288918181824156
# Current sample: [-0.6557663   0.91491503] chain 0, sample 74
# log dataset likelihood: -229.96923219606288, intermediate_ratio: -2.2996923219606287
# Current sample: [-0.6557663   0.91491503] chain 0, sample 75
# log dataset likelihood: -229.96923219606288, intermediate_ratio: -2.2996923219606287
# Current sample: [-0.6557663   0.91491503] chain 0, sample 76
# log dataset likelihood: -229.96923219606288, intermediate_ratio: -2.2996923219606287
# Current sample: [-0.6557663   0.91491503] chain 0, sample 77
# log dataset likelihood: -229.96923219606288, intermediate_ratio: -2.2996923219606287
# Current sample: [-0.7182694   0.96576709] chain 0, sample 78
# log dataset likelihood: -233.24464967546922, intermediate_ratio: -2.332446496754692
# Current sample: [-0.7182694   0.96576709] chain 0, sample 79
# log dataset likelihood: -233.24464967546922, intermediate_ratio: -2.332446496754692
# Current sample: [-0.66296399  0.898503  ] chain 0, sample 80
# log dataset likelihood: -228.54461051736726, intermediate_ratio: -2.2854461051736727
# Current sample: [-0.66296399  0.898503  ] chain 0, sample 81
# log dataset likelihood: -228.54461051736726, intermediate_ratio: -2.2854461051736727
# Current sample: [-0.66296399  0.898503  ] chain 0, sample 82
# log dataset likelihood: -228.54461051736726, intermediate_ratio: -2.2854461051736727
# Current sample: [-0.66296399  0.898503  ] chain 0, sample 83
# log dataset likelihood: -228.54461051736726, intermediate_ratio: -2.2854461051736727
# Current sample: [-0.66296399  0.898503  ] chain 0, sample 84
# log dataset likelihood: -228.54461051736726, intermediate_ratio: -2.2854461051736727
# Current sample: [-0.66296399  0.898503  ] chain 0, sample 85
# log dataset likelihood: -228.54461051736726, intermediate_ratio: -2.2854461051736727
# Current sample: [-0.66296399  0.898503  ] chain 0, sample 86
# log dataset likelihood: -228.54461051736726, intermediate_ratio: -2.2854461051736727
# Current sample: [-0.66296399  0.898503  ] chain 0, sample 87
# log dataset likelihood: -228.54461051736726, intermediate_ratio: -2.2854461051736727
# Current sample: [-0.66296399  0.898503  ] chain 0, sample 88
# log dataset likelihood: -228.54461051736726, intermediate_ratio: -2.2854461051736727
# Current sample: [-0.66296399  0.898503  ] chain 0, sample 89
# log dataset likelihood: -228.54461051736726, intermediate_ratio: -2.2854461051736727
# Current sample: [-0.66296399  0.898503  ] chain 0, sample 90
# log dataset likelihood: -228.54461051736726, intermediate_ratio: -2.2854461051736727
# Current sample: [-0.62379449  0.82892525] chain 0, sample 91
# log dataset likelihood: -245.80034480382943, intermediate_ratio: -2.458003448038294
# Current sample: [-0.62379449  0.82892525] chain 0, sample 92
# log dataset likelihood: -245.80034480382943, intermediate_ratio: -2.458003448038294
# Current sample: [-0.63063531  0.87914722] chain 0, sample 93
# log dataset likelihood: -236.2514671523701, intermediate_ratio: -2.362514671523701
# Current sample: [-0.66794179  0.85760018] chain 0, sample 94
# log dataset likelihood: -230.7677363813012, intermediate_ratio: -2.307677363813012
# Current sample: [-0.66794179  0.85760018] chain 0, sample 95
# log dataset likelihood: -230.7677363813012, intermediate_ratio: -2.307677363813012
# Current sample: [-0.79056704  0.91712772] chain 0, sample 96
# log dataset likelihood: -242.82820649913876, intermediate_ratio: -2.4282820649913877
# Current sample: [-0.79856269  0.85359219] chain 0, sample 97
# log dataset likelihood: -247.99460862190477, intermediate_ratio: -2.479946086219048
# Current sample: [-0.69710393  1.01339549] chain 0, sample 98
# log dataset likelihood: -245.52518672284694, intermediate_ratio: -2.4552518672284696
# Current sample: [-0.56650582  0.91368466] chain 0, sample 99
# log dataset likelihood: -261.5068662938981, intermediate_ratio: -2.615068662938981
# Current sample: [-0.88055559  1.00958253] chain 0, sample 100
# log dataset likelihood: -311.75459652475547, intermediate_ratio: -3.1175459652475546
# Finished simulating chain, omega sample is: 5.172961124668158e-101, log omega: -230.91764911645126
# Current sample: [-0.64517684  0.86496006] chain 1, sample 1
# log dataset likelihood: -233.91346501848574, intermediate_ratio: -2.3391346501848576
# Current sample: [-0.64517684  0.86496006] chain 1, sample 2
# log dataset likelihood: -233.91346501848574, intermediate_ratio: -2.3391346501848576
# Current sample: [-0.64517684  0.86496006] chain 1, sample 3
# log dataset likelihood: -233.91346501848574, intermediate_ratio: -2.3391346501848576
# Current sample: [-0.75725706  0.91010341] chain 1, sample 4
# log dataset likelihood: -232.57256286524796, intermediate_ratio: -2.3257256286524797
# Current sample: [-0.74925135  0.94099415] chain 1, sample 5
# log dataset likelihood: -233.46070901818058, intermediate_ratio: -2.3346070901818057
# Current sample: [-0.74925135  0.94099415] chain 1, sample 6
# log dataset likelihood: -233.46070901818058, intermediate_ratio: -2.3346070901818057
# Current sample: [-0.74925135  0.94099415] chain 1, sample 7
# log dataset likelihood: -233.46070901818058, intermediate_ratio: -2.3346070901818057
# Current sample: [-0.74925135  0.94099415] chain 1, sample 8
# log dataset likelihood: -233.46070901818058, intermediate_ratio: -2.3346070901818057
# Current sample: [-0.74925135  0.94099415] chain 1, sample 9
# log dataset likelihood: -233.46070901818058, intermediate_ratio: -2.3346070901818057
# Current sample: [-0.74925135  0.94099415] chain 1, sample 10
# log dataset likelihood: -233.46070901818058, intermediate_ratio: -2.3346070901818057
# Current sample: [-0.6903834   0.94033553] chain 1, sample 11
# log dataset likelihood: -228.43056119735843, intermediate_ratio: -2.2843056119735845
# Current sample: [-0.6903834   0.94033553] chain 1, sample 12
# log dataset likelihood: -228.43056119735843, intermediate_ratio: -2.2843056119735845
# Current sample: [-0.68393259  0.87213964] chain 1, sample 13
# log dataset likelihood: -227.55254407060187, intermediate_ratio: -2.275525440706019
# Current sample: [-0.68393259  0.87213964] chain 1, sample 14
# log dataset likelihood: -227.55254407060187, intermediate_ratio: -2.275525440706019
# Current sample: [-0.68720087  0.93368565] chain 1, sample 15
# log dataset likelihood: -227.81193109395204, intermediate_ratio: -2.2781193109395206
# Current sample: [-0.68720087  0.93368565] chain 1, sample 16
# log dataset likelihood: -227.81193109395204, intermediate_ratio: -2.2781193109395206
# Current sample: [-0.69226425  0.88979306] chain 1, sample 17
# log dataset likelihood: -226.0803295071233, intermediate_ratio: -2.2608032950712333
# Current sample: [-0.69226425  0.88979306] chain 1, sample 18
# log dataset likelihood: -226.0803295071233, intermediate_ratio: -2.2608032950712333
# Current sample: [-0.69226425  0.88979306] chain 1, sample 19
# log dataset likelihood: -226.0803295071233, intermediate_ratio: -2.2608032950712333
# Current sample: [-0.69226425  0.88979306] chain 1, sample 20
# log dataset likelihood: -226.0803295071233, intermediate_ratio: -2.2608032950712333
# Current sample: [-0.69226425  0.88979306] chain 1, sample 21
# log dataset likelihood: -226.0803295071233, intermediate_ratio: -2.2608032950712333
# Current sample: [-0.71399649  0.8940995 ] chain 1, sample 22
# log dataset likelihood: -226.22699025224279, intermediate_ratio: -2.2622699025224278
# Current sample: [-0.71399649  0.8940995 ] chain 1, sample 23
# log dataset likelihood: -226.22699025224279, intermediate_ratio: -2.2622699025224278
# Current sample: [-0.71399649  0.8940995 ] chain 1, sample 24
# log dataset likelihood: -226.22699025224279, intermediate_ratio: -2.2622699025224278
# Current sample: [-0.71399649  0.8940995 ] chain 1, sample 25
# log dataset likelihood: -226.22699025224279, intermediate_ratio: -2.2622699025224278
# Current sample: [-0.71399649  0.8940995 ] chain 1, sample 26
# log dataset likelihood: -226.22699025224279, intermediate_ratio: -2.2622699025224278
# Current sample: [-0.71399649  0.8940995 ] chain 1, sample 27
# log dataset likelihood: -226.22699025224279, intermediate_ratio: -2.2622699025224278
# Current sample: [-0.71399649  0.8940995 ] chain 1, sample 28
# log dataset likelihood: -226.22699025224279, intermediate_ratio: -2.2622699025224278
# Current sample: [-0.74388734  0.89206852] chain 1, sample 29
# log dataset likelihood: -229.69950025008296, intermediate_ratio: -2.2969950025008297
# Current sample: [-0.74388734  0.89206852] chain 1, sample 30
# log dataset likelihood: -229.69950025008296, intermediate_ratio: -2.2969950025008297
# Current sample: [-0.74388734  0.89206852] chain 1, sample 31
# log dataset likelihood: -229.69950025008296, intermediate_ratio: -2.2969950025008297
# Current sample: [-0.74388734  0.89206852] chain 1, sample 32
# log dataset likelihood: -229.69950025008296, intermediate_ratio: -2.2969950025008297
# Current sample: [-0.74388734  0.89206852] chain 1, sample 33
# log dataset likelihood: -229.69950025008296, intermediate_ratio: -2.2969950025008297
# Current sample: [-0.69551998  0.9181334 ] chain 1, sample 34
# log dataset likelihood: -226.32718443484603, intermediate_ratio: -2.2632718443484605
# Current sample: [-0.69551998  0.9181334 ] chain 1, sample 35
# log dataset likelihood: -226.32718443484603, intermediate_ratio: -2.2632718443484605
# Current sample: [-0.69551998  0.9181334 ] chain 1, sample 36
# log dataset likelihood: -226.32718443484603, intermediate_ratio: -2.2632718443484605
# Current sample: [-0.69551998  0.9181334 ] chain 1, sample 37
# log dataset likelihood: -226.32718443484603, intermediate_ratio: -2.2632718443484605
# Current sample: [-0.69551998  0.9181334 ] chain 1, sample 38
# log dataset likelihood: -226.32718443484603, intermediate_ratio: -2.2632718443484605
# Current sample: [-0.69551998  0.9181334 ] chain 1, sample 39
# log dataset likelihood: -226.32718443484603, intermediate_ratio: -2.2632718443484605
# Current sample: [-0.71525556  0.87257139] chain 1, sample 40
# log dataset likelihood: -227.36374731990804, intermediate_ratio: -2.2736374731990803
# Current sample: [-0.71525556  0.87257139] chain 1, sample 41
# log dataset likelihood: -227.36374731990804, intermediate_ratio: -2.2736374731990803
# Current sample: [-0.71525556  0.87257139] chain 1, sample 42
# log dataset likelihood: -227.36374731990804, intermediate_ratio: -2.2736374731990803
# Current sample: [-0.71525556  0.87257139] chain 1, sample 43
# log dataset likelihood: -227.36374731990804, intermediate_ratio: -2.2736374731990803
# Current sample: [-0.71525556  0.87257139] chain 1, sample 44
# log dataset likelihood: -227.36374731990804, intermediate_ratio: -2.2736374731990803
# Current sample: [-0.73197867  0.86601838] chain 1, sample 45
# log dataset likelihood: -229.4836900642142, intermediate_ratio: -2.294836900642142
# Current sample: [-0.73197867  0.86601838] chain 1, sample 46
# log dataset likelihood: -229.4836900642142, intermediate_ratio: -2.294836900642142
# Current sample: [-0.73197867  0.86601838] chain 1, sample 47
# log dataset likelihood: -229.4836900642142, intermediate_ratio: -2.294836900642142
# Current sample: [-0.73197867  0.86601838] chain 1, sample 48
# log dataset likelihood: -229.4836900642142, intermediate_ratio: -2.294836900642142
# Current sample: [-0.67395745  0.87022133] chain 1, sample 49
# log dataset likelihood: -228.60086020382053, intermediate_ratio: -2.2860086020382053
# Current sample: [-0.65906773  0.88403761] chain 1, sample 50
# log dataset likelihood: -229.61011109469314, intermediate_ratio: -2.2961011109469314
# Current sample: [-0.65906773  0.88403761] chain 1, sample 51
# log dataset likelihood: -229.61011109469314, intermediate_ratio: -2.2961011109469314
# Current sample: [-0.73242338  0.90873918] chain 1, sample 52
# log dataset likelihood: -228.04437177912044, intermediate_ratio: -2.2804437177912043
# Current sample: [-0.73242338  0.90873918] chain 1, sample 53
# log dataset likelihood: -228.04437177912044, intermediate_ratio: -2.2804437177912043
# Current sample: [-0.73242338  0.90873918] chain 1, sample 54
# log dataset likelihood: -228.04437177912044, intermediate_ratio: -2.2804437177912043
# Current sample: [-0.73242338  0.90873918] chain 1, sample 55
# log dataset likelihood: -228.04437177912044, intermediate_ratio: -2.2804437177912043
# Current sample: [-0.73242338  0.90873918] chain 1, sample 56
# log dataset likelihood: -228.04437177912044, intermediate_ratio: -2.2804437177912043
# Current sample: [-0.73242338  0.90873918] chain 1, sample 57
# log dataset likelihood: -228.04437177912044, intermediate_ratio: -2.2804437177912043
# Current sample: [-0.73242338  0.90873918] chain 1, sample 58
# log dataset likelihood: -228.04437177912044, intermediate_ratio: -2.2804437177912043
# Current sample: [-0.73242338  0.90873918] chain 1, sample 59
# log dataset likelihood: -228.04437177912044, intermediate_ratio: -2.2804437177912043
# Current sample: [-0.73242338  0.90873918] chain 1, sample 60
# log dataset likelihood: -228.04437177912044, intermediate_ratio: -2.2804437177912043
# Current sample: [-0.73242338  0.90873918] chain 1, sample 61
# log dataset likelihood: -228.04437177912044, intermediate_ratio: -2.2804437177912043
# Current sample: [-0.73242338  0.90873918] chain 1, sample 62
# log dataset likelihood: -228.04437177912044, intermediate_ratio: -2.2804437177912043
# Current sample: [-0.73242338  0.90873918] chain 1, sample 63
# log dataset likelihood: -228.04437177912044, intermediate_ratio: -2.2804437177912043
# Current sample: [-0.73242338  0.90873918] chain 1, sample 64
# log dataset likelihood: -228.04437177912044, intermediate_ratio: -2.2804437177912043
# Current sample: [-0.73242338  0.90873918] chain 1, sample 65
# log dataset likelihood: -228.04437177912044, intermediate_ratio: -2.2804437177912043
# Current sample: [-0.73242338  0.90873918] chain 1, sample 66
# log dataset likelihood: -228.04437177912044, intermediate_ratio: -2.2804437177912043
# Current sample: [-0.72393444  0.94095023] chain 1, sample 67
# log dataset likelihood: -229.6280344120312, intermediate_ratio: -2.296280344120312
# Current sample: [-0.72393444  0.94095023] chain 1, sample 68
# log dataset likelihood: -229.6280344120312, intermediate_ratio: -2.296280344120312
# Current sample: [-0.72393444  0.94095023] chain 1, sample 69
# log dataset likelihood: -229.6280344120312, intermediate_ratio: -2.296280344120312
# Current sample: [-0.72393444  0.94095023] chain 1, sample 70
# log dataset likelihood: -229.6280344120312, intermediate_ratio: -2.296280344120312
# Current sample: [-0.72393444  0.94095023] chain 1, sample 71
# log dataset likelihood: -229.6280344120312, intermediate_ratio: -2.296280344120312
# Current sample: [-0.72393444  0.94095023] chain 1, sample 72
# log dataset likelihood: -229.6280344120312, intermediate_ratio: -2.296280344120312
# Current sample: [-0.72393444  0.94095023] chain 1, sample 73
# log dataset likelihood: -229.6280344120312, intermediate_ratio: -2.296280344120312
# Current sample: [-0.72393444  0.94095023] chain 1, sample 74
# log dataset likelihood: -229.6280344120312, intermediate_ratio: -2.296280344120312
# Current sample: [-0.72393444  0.94095023] chain 1, sample 75
# log dataset likelihood: -229.6280344120312, intermediate_ratio: -2.296280344120312
# Current sample: [-0.72393444  0.94095023] chain 1, sample 76
# log dataset likelihood: -229.6280344120312, intermediate_ratio: -2.296280344120312
# Current sample: [-0.66284825  0.9110271 ] chain 1, sample 77
# log dataset likelihood: -228.69077486199134, intermediate_ratio: -2.2869077486199134
# Current sample: [-0.66284825  0.9110271 ] chain 1, sample 78
# log dataset likelihood: -228.69077486199134, intermediate_ratio: -2.2869077486199134
# Current sample: [-0.66284825  0.9110271 ] chain 1, sample 79
# log dataset likelihood: -228.69077486199134, intermediate_ratio: -2.2869077486199134
# Current sample: [-0.66284825  0.9110271 ] chain 1, sample 80
# log dataset likelihood: -228.69077486199134, intermediate_ratio: -2.2869077486199134
# Current sample: [-0.66284825  0.9110271 ] chain 1, sample 81
# log dataset likelihood: -228.69077486199134, intermediate_ratio: -2.2869077486199134
# Current sample: [-0.66284825  0.9110271 ] chain 1, sample 82
# log dataset likelihood: -228.69077486199134, intermediate_ratio: -2.2869077486199134
# Current sample: [-0.66284825  0.9110271 ] chain 1, sample 83
# log dataset likelihood: -228.69077486199134, intermediate_ratio: -2.2869077486199134
# Current sample: [-0.66284825  0.9110271 ] chain 1, sample 84
# log dataset likelihood: -228.69077486199134, intermediate_ratio: -2.2869077486199134
# Current sample: [-0.64979416  0.86460787] chain 1, sample 85
# log dataset likelihood: -232.9648226530482, intermediate_ratio: -2.329648226530482
# Current sample: [-0.74003597  0.84467993] chain 1, sample 86
# log dataset likelihood: -233.43991855325623, intermediate_ratio: -2.3343991855325625
# Current sample: [-0.74003597  0.84467993] chain 1, sample 87
# log dataset likelihood: -233.43991855325623, intermediate_ratio: -2.3343991855325625
# Current sample: [-0.64013156  0.94913149] chain 1, sample 88
# log dataset likelihood: -236.32454360425544, intermediate_ratio: -2.3632454360425545
# Current sample: [-0.7243757   0.86656382] chain 1, sample 89
# log dataset likelihood: -228.60203509490015, intermediate_ratio: -2.2860203509490016
# Current sample: [-0.71181259  0.84984221] chain 1, sample 90
# log dataset likelihood: -229.8663553235186, intermediate_ratio: -2.298663553235186
# Current sample: [-0.71181259  0.84984221] chain 1, sample 91
# log dataset likelihood: -229.8663553235186, intermediate_ratio: -2.298663553235186
# Current sample: [-0.71181259  0.84984221] chain 1, sample 92
# log dataset likelihood: -229.8663553235186, intermediate_ratio: -2.298663553235186
# Current sample: [-0.71181259  0.84984221] chain 1, sample 93
# log dataset likelihood: -229.8663553235186, intermediate_ratio: -2.298663553235186
# Current sample: [-0.775111    0.91048694] chain 1, sample 94
# log dataset likelihood: -237.33573793802128, intermediate_ratio: -2.373357379380213
# Current sample: [-0.6731826   0.78614981] chain 1, sample 95
# log dataset likelihood: -247.50088808611017, intermediate_ratio: -2.4750088808611017
# Current sample: [-0.66805874  0.78407331] chain 1, sample 96
# log dataset likelihood: -248.91203959592966, intermediate_ratio: -2.4891203959592967
# Current sample: [-0.7103922   0.93851954] chain 1, sample 97
# log dataset likelihood: -228.33374651547493, intermediate_ratio: -2.2833374651547493
# Current sample: [-0.75334811  0.90528701] chain 1, sample 98
# log dataset likelihood: -231.55931709816042, intermediate_ratio: -2.315593170981604
# Current sample: [-0.96238006  0.77944138] chain 1, sample 99
# log dataset likelihood: -382.10963565796794, intermediate_ratio: -3.8210963565796794
# Current sample: [-0.80669725  0.85894393] chain 1, sample 100
# log dataset likelihood: -250.6374817584809, intermediate_ratio: -2.5063748175848093
# Finished simulating chain, omega sample is: 3.7931151458180055e-101, log omega: -231.22790677269995
# Current sample: [-0.66105189  0.87094579] chain 2, sample 1
# log dataset likelihood: -230.25449414857457, intermediate_ratio: -2.3025449414857455
# Current sample: [-0.66105189  0.87094579] chain 2, sample 2
# log dataset likelihood: -230.25449414857457, intermediate_ratio: -2.3025449414857455
# Current sample: [-0.71521798  0.92344464] chain 2, sample 3
# log dataset likelihood: -227.14070867324844, intermediate_ratio: -2.2714070867324843
# Current sample: [-0.71521798  0.92344464] chain 2, sample 4
# log dataset likelihood: -227.14070867324844, intermediate_ratio: -2.2714070867324843
# Current sample: [-0.71521798  0.92344464] chain 2, sample 5
# log dataset likelihood: -227.14070867324844, intermediate_ratio: -2.2714070867324843
# Current sample: [-0.72542404  0.92810493] chain 2, sample 6
# log dataset likelihood: -228.38121931992583, intermediate_ratio: -2.2838121931992585
# Current sample: [-0.72542404  0.92810493] chain 2, sample 7
# log dataset likelihood: -228.38121931992583, intermediate_ratio: -2.2838121931992585
# Current sample: [-0.71875888  0.93872246] chain 2, sample 8
# log dataset likelihood: -228.88375049191114, intermediate_ratio: -2.2888375049191114
# Current sample: [-0.71875888  0.93872246] chain 2, sample 9
# log dataset likelihood: -228.88375049191114, intermediate_ratio: -2.2888375049191114
# Current sample: [-0.71875888  0.93872246] chain 2, sample 10
# log dataset likelihood: -228.88375049191114, intermediate_ratio: -2.2888375049191114
# Current sample: [-0.71875888  0.93872246] chain 2, sample 11
# log dataset likelihood: -228.88375049191114, intermediate_ratio: -2.2888375049191114
# Current sample: [-0.71875888  0.93872246] chain 2, sample 12
# log dataset likelihood: -228.88375049191114, intermediate_ratio: -2.2888375049191114
# Current sample: [-0.71875888  0.93872246] chain 2, sample 13
# log dataset likelihood: -228.88375049191114, intermediate_ratio: -2.2888375049191114
# Current sample: [-0.71875888  0.93872246] chain 2, sample 14
# log dataset likelihood: -228.88375049191114, intermediate_ratio: -2.2888375049191114
# Current sample: [-0.71875888  0.93872246] chain 2, sample 15
# log dataset likelihood: -228.88375049191114, intermediate_ratio: -2.2888375049191114
# Current sample: [-0.71875888  0.93872246] chain 2, sample 16
# log dataset likelihood: -228.88375049191114, intermediate_ratio: -2.2888375049191114
# Current sample: [-0.71875888  0.93872246] chain 2, sample 17
# log dataset likelihood: -228.88375049191114, intermediate_ratio: -2.2888375049191114
# Current sample: [-0.71875888  0.93872246] chain 2, sample 18
# log dataset likelihood: -228.88375049191114, intermediate_ratio: -2.2888375049191114
# Current sample: [-0.71875888  0.93872246] chain 2, sample 19
# log dataset likelihood: -228.88375049191114, intermediate_ratio: -2.2888375049191114
# Current sample: [-0.71875888  0.93872246] chain 2, sample 20
# log dataset likelihood: -228.88375049191114, intermediate_ratio: -2.2888375049191114
# Current sample: [-0.71875888  0.93872246] chain 2, sample 21
# log dataset likelihood: -228.88375049191114, intermediate_ratio: -2.2888375049191114
# Current sample: [-0.66120936  0.90780739] chain 2, sample 22
# log dataset likelihood: -228.85902002759576, intermediate_ratio: -2.2885902002759577
# Current sample: [-0.66120936  0.90780739] chain 2, sample 23
# log dataset likelihood: -228.85902002759576, intermediate_ratio: -2.2885902002759577
# Current sample: [-0.69774833  0.94826025] chain 2, sample 24
# log dataset likelihood: -229.3670700933482, intermediate_ratio: -2.293670700933482
# Current sample: [-0.69774833  0.94826025] chain 2, sample 25
# log dataset likelihood: -229.3670700933482, intermediate_ratio: -2.293670700933482
# Current sample: [-0.69774833  0.94826025] chain 2, sample 26
# log dataset likelihood: -229.3670700933482, intermediate_ratio: -2.293670700933482
# Current sample: [-0.69774833  0.94826025] chain 2, sample 27
# log dataset likelihood: -229.3670700933482, intermediate_ratio: -2.293670700933482
# Current sample: [-0.69774833  0.94826025] chain 2, sample 28
# log dataset likelihood: -229.3670700933482, intermediate_ratio: -2.293670700933482
# Current sample: [-0.69774833  0.94826025] chain 2, sample 29
# log dataset likelihood: -229.3670700933482, intermediate_ratio: -2.293670700933482
# Current sample: [-0.69774833  0.94826025] chain 2, sample 30
# log dataset likelihood: -229.3670700933482, intermediate_ratio: -2.293670700933482
# Current sample: [-0.69727463  0.90025309] chain 2, sample 31
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 32
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 33
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 34
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 35
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 36
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 37
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 38
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 39
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 40
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 41
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 42
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 43
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 44
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 45
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 46
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 47
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 48
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 49
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 50
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 51
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 52
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 53
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 54
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 55
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 56
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 57
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 58
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 59
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 60
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 61
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 62
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.69727463  0.90025309] chain 2, sample 63
# log dataset likelihood: -225.80622564355383, intermediate_ratio: -2.2580622564355384
# Current sample: [-0.64510995  0.86422389] chain 2, sample 64
# log dataset likelihood: -234.01323830577942, intermediate_ratio: -2.3401323830577945
# Current sample: [-0.67554204  0.82005499] chain 2, sample 65
# log dataset likelihood: -237.035600762916, intermediate_ratio: -2.37035600762916
# Current sample: [-0.73603589  0.95941914] chain 2, sample 66
# log dataset likelihood: -234.0632341416727, intermediate_ratio: -2.340632341416727
# Current sample: [-0.73603589  0.95941914] chain 2, sample 67
# log dataset likelihood: -234.0632341416727, intermediate_ratio: -2.340632341416727
# Current sample: [-0.71552691  0.9174162 ] chain 2, sample 68
# log dataset likelihood: -226.77115830680285, intermediate_ratio: -2.2677115830680283
# Current sample: [-0.71552691  0.9174162 ] chain 2, sample 69
# log dataset likelihood: -226.77115830680285, intermediate_ratio: -2.2677115830680283
# Current sample: [-0.70264207  0.86228514] chain 2, sample 70
# log dataset likelihood: -227.97901036444836, intermediate_ratio: -2.2797901036444834
# Current sample: [-0.70264207  0.86228514] chain 2, sample 71
# log dataset likelihood: -227.97901036444836, intermediate_ratio: -2.2797901036444834
# Current sample: [-0.67481698  0.88390584] chain 2, sample 72
# log dataset likelihood: -227.50506341672045, intermediate_ratio: -2.2750506341672043
# Current sample: [-0.67481698  0.88390584] chain 2, sample 73
# log dataset likelihood: -227.50506341672045, intermediate_ratio: -2.2750506341672043
# Current sample: [-0.67481698  0.88390584] chain 2, sample 74
# log dataset likelihood: -227.50506341672045, intermediate_ratio: -2.2750506341672043
# Current sample: [-0.67481698  0.88390584] chain 2, sample 75
# log dataset likelihood: -227.50506341672045, intermediate_ratio: -2.2750506341672043
# Current sample: [-0.67481698  0.88390584] chain 2, sample 76
# log dataset likelihood: -227.50506341672045, intermediate_ratio: -2.2750506341672043
# Current sample: [-0.67481698  0.88390584] chain 2, sample 77
# log dataset likelihood: -227.50506341672045, intermediate_ratio: -2.2750506341672043
# Current sample: [-0.67481698  0.88390584] chain 2, sample 78
# log dataset likelihood: -227.50506341672045, intermediate_ratio: -2.2750506341672043
# Current sample: [-0.67481698  0.88390584] chain 2, sample 79
# log dataset likelihood: -227.50506341672045, intermediate_ratio: -2.2750506341672043
# Current sample: [-0.78558508  0.94740273] chain 2, sample 80
# log dataset likelihood: -244.36756104329555, intermediate_ratio: -2.4436756104329556
# Current sample: [-0.79557727  0.86047664] chain 2, sample 81
# log dataset likelihood: -246.0196615322929, intermediate_ratio: -2.460196615322929
# Current sample: [-0.79557727  0.86047664] chain 2, sample 82
# log dataset likelihood: -246.0196615322929, intermediate_ratio: -2.460196615322929
# Current sample: [-0.73368628  0.91907576] chain 2, sample 83
# log dataset likelihood: -228.69507678490626, intermediate_ratio: -2.2869507678490626
# Current sample: [-0.6977725   0.91501352] chain 2, sample 84
# log dataset likelihood: -226.14367243959663, intermediate_ratio: -2.2614367243959665
# Current sample: [-0.6977725   0.91501352] chain 2, sample 85
# log dataset likelihood: -226.14367243959663, intermediate_ratio: -2.2614367243959665
# Current sample: [-0.78149098  0.87873364] chain 2, sample 86
# log dataset likelihood: -239.5651219451184, intermediate_ratio: -2.395651219451184
# Current sample: [-0.78149098  0.87873364] chain 2, sample 87
# log dataset likelihood: -239.5651219451184, intermediate_ratio: -2.395651219451184
# Current sample: [-0.78149098  0.87873364] chain 2, sample 88
# log dataset likelihood: -239.5651219451184, intermediate_ratio: -2.395651219451184
# Current sample: [-0.71517282  0.97411713] chain 2, sample 89
# log dataset likelihood: -234.82307763298917, intermediate_ratio: -2.3482307763298915
# Current sample: [-0.75875525  0.88164612] chain 2, sample 90
# log dataset likelihood: -233.08717444261035, intermediate_ratio: -2.3308717444261036
# Current sample: [-0.75875525  0.88164612] chain 2, sample 91
# log dataset likelihood: -233.08717444261035, intermediate_ratio: -2.3308717444261036
# Current sample: [-0.71139703  0.88923486] chain 2, sample 92
# log dataset likelihood: -226.21483904223743, intermediate_ratio: -2.2621483904223743
# Current sample: [-0.71905709  0.87082519] chain 2, sample 93
# log dataset likelihood: -227.76040132889946, intermediate_ratio: -2.2776040132889945
# Current sample: [-0.71485826  0.93182365] chain 2, sample 94
# log dataset likelihood: -227.8441229632736, intermediate_ratio: -2.2784412296327363
# Current sample: [-0.76171023  0.79988983] chain 2, sample 95
# log dataset likelihood: -248.08289887651992, intermediate_ratio: -2.4808289887651993
# Current sample: [-0.76199764  0.81349466] chain 2, sample 96
# log dataset likelihood: -244.34861873577083, intermediate_ratio: -2.4434861873577085
# Current sample: [-0.74905368  0.79708512] chain 2, sample 97
# log dataset likelihood: -246.28602899618252, intermediate_ratio: -2.4628602899618253
# Current sample: [-0.65669822  0.89092214] chain 2, sample 98
# log dataset likelihood: -229.71400909229072, intermediate_ratio: -2.297140090922907
# Current sample: [-0.7497092   0.84504655] chain 2, sample 99
# log dataset likelihood: -235.05362100331294, intermediate_ratio: -2.3505362100331295
# Current sample: [-0.72381233  0.73483662] chain 2, sample 100
# log dataset likelihood: -268.37608040922044, intermediate_ratio: -2.6837608040922043
# Finished simulating chain, omega sample is: 1.622762957002031e-100, log omega: -229.7743790739097
# Current sample: [-0.6844777   0.90195937] chain 3, sample 1
# log dataset likelihood: -226.27557824812274, intermediate_ratio: -2.2627557824812277
# Current sample: [-0.6844777   0.90195937] chain 3, sample 2
# log dataset likelihood: -226.27557824812274, intermediate_ratio: -2.2627557824812277
# Current sample: [-0.6844777   0.90195937] chain 3, sample 3
# log dataset likelihood: -226.27557824812274, intermediate_ratio: -2.2627557824812277
# Current sample: [-0.6844777   0.90195937] chain 3, sample 4
# log dataset likelihood: -226.27557824812274, intermediate_ratio: -2.2627557824812277
# Current sample: [-0.6844777   0.90195937] chain 3, sample 5
# log dataset likelihood: -226.27557824812274, intermediate_ratio: -2.2627557824812277
# Current sample: [-0.6844777   0.90195937] chain 3, sample 6
# log dataset likelihood: -226.27557824812274, intermediate_ratio: -2.2627557824812277
# Current sample: [-0.70386311  0.91127738] chain 3, sample 7
# log dataset likelihood: -226.02168801810748, intermediate_ratio: -2.260216880181075
# Current sample: [-0.70386311  0.91127738] chain 3, sample 8
# log dataset likelihood: -226.02168801810748, intermediate_ratio: -2.260216880181075
# Current sample: [-0.70386311  0.91127738] chain 3, sample 9
# log dataset likelihood: -226.02168801810748, intermediate_ratio: -2.260216880181075
# Current sample: [-0.70386311  0.91127738] chain 3, sample 10
# log dataset likelihood: -226.02168801810748, intermediate_ratio: -2.260216880181075
# Current sample: [-0.70386311  0.91127738] chain 3, sample 11
# log dataset likelihood: -226.02168801810748, intermediate_ratio: -2.260216880181075
# Current sample: [-0.70386311  0.91127738] chain 3, sample 12
# log dataset likelihood: -226.02168801810748, intermediate_ratio: -2.260216880181075
# Current sample: [-0.70386311  0.91127738] chain 3, sample 13
# log dataset likelihood: -226.02168801810748, intermediate_ratio: -2.260216880181075
# Current sample: [-0.70386311  0.91127738] chain 3, sample 14
# log dataset likelihood: -226.02168801810748, intermediate_ratio: -2.260216880181075
# Current sample: [-0.70386311  0.91127738] chain 3, sample 15
# log dataset likelihood: -226.02168801810748, intermediate_ratio: -2.260216880181075
# Current sample: [-0.70386311  0.91127738] chain 3, sample 16
# log dataset likelihood: -226.02168801810748, intermediate_ratio: -2.260216880181075
# Current sample: [-0.70386311  0.91127738] chain 3, sample 17
# log dataset likelihood: -226.02168801810748, intermediate_ratio: -2.260216880181075
# Current sample: [-0.70386311  0.91127738] chain 3, sample 18
# log dataset likelihood: -226.02168801810748, intermediate_ratio: -2.260216880181075
# Current sample: [-0.70386311  0.91127738] chain 3, sample 19
# log dataset likelihood: -226.02168801810748, intermediate_ratio: -2.260216880181075
# Current sample: [-0.70386311  0.91127738] chain 3, sample 20
# log dataset likelihood: -226.02168801810748, intermediate_ratio: -2.260216880181075
# Current sample: [-0.70386311  0.91127738] chain 3, sample 21
# log dataset likelihood: -226.02168801810748, intermediate_ratio: -2.260216880181075
# Current sample: [-0.70386311  0.91127738] chain 3, sample 22
# log dataset likelihood: -226.02168801810748, intermediate_ratio: -2.260216880181075
# Current sample: [-0.70386311  0.91127738] chain 3, sample 23
# log dataset likelihood: -226.02168801810748, intermediate_ratio: -2.260216880181075
# Current sample: [-0.70386311  0.91127738] chain 3, sample 24
# log dataset likelihood: -226.02168801810748, intermediate_ratio: -2.260216880181075
# Current sample: [-0.70386311  0.91127738] chain 3, sample 25
# log dataset likelihood: -226.02168801810748, intermediate_ratio: -2.260216880181075
# Current sample: [-0.70386311  0.91127738] chain 3, sample 26
# log dataset likelihood: -226.02168801810748, intermediate_ratio: -2.260216880181075
# Current sample: [-0.68952934  0.87834685] chain 3, sample 27
# log dataset likelihood: -226.7574713005599, intermediate_ratio: -2.267574713005599
# Current sample: [-0.68952934  0.87834685] chain 3, sample 28
# ...
# log dataset likelihood: -238.33684630640647, intermediate_ratio: -2.383368463064065
# Current sample: [-0.76595274  0.84739471] chain 8, sample 95
# log dataset likelihood: -238.33684630640647, intermediate_ratio: -2.383368463064065
# Current sample: [-0.68991723  0.90714025] chain 8, sample 96
# log dataset likelihood: -226.06458844198514, intermediate_ratio: -2.2606458844198514
# Current sample: [-0.68991723  0.90714025] chain 8, sample 97
# log dataset likelihood: -226.06458844198514, intermediate_ratio: -2.2606458844198514
# Current sample: [-0.92268048  1.20951949] chain 8, sample 98
# log dataset likelihood: -480.21092796165533, intermediate_ratio: -4.802109279616554
# Current sample: [-0.70189673  0.78523928] chain 8, sample 99
# log dataset likelihood: -246.00711231576435, intermediate_ratio: -2.4600711231576433
# Current sample: [-0.86811722  1.078964  ] chain 8, sample 100
# log dataset likelihood: -335.042952630416, intermediate_ratio: -3.35042952630416
# Finished simulating chain, omega sample is: 2.1193903329892665e-101, log omega: -231.80996592385205
# Current sample: [-0.66549241  0.87321185] chain 9, sample 1
# log dataset likelihood: -229.3834873914843, intermediate_ratio: -2.293834873914843
# Current sample: [-0.66549241  0.87321185] chain 9, sample 2
# log dataset likelihood: -229.3834873914843, intermediate_ratio: -2.293834873914843
# Current sample: [-0.73730716  0.91367677] chain 9, sample 3
# log dataset likelihood: -228.92204286171938, intermediate_ratio: -2.289220428617194
# Current sample: [-0.70829736  0.94133166] chain 9, sample 4
# log dataset likelihood: -228.59373149676046, intermediate_ratio: -2.2859373149676046
# Current sample: [-0.70829736  0.94133166] chain 9, sample 5
# log dataset likelihood: -228.59373149676046, intermediate_ratio: -2.2859373149676046
# Current sample: [-0.70829736  0.94133166] chain 9, sample 6
# log dataset likelihood: -228.59373149676046, intermediate_ratio: -2.2859373149676046
# Current sample: [-0.7220121   0.89568869] chain 9, sample 7
# log dataset likelihood: -226.77787876568735, intermediate_ratio: -2.2677787876568734
# Current sample: [-0.7220121   0.89568869] chain 9, sample 8
# log dataset likelihood: -226.77787876568735, intermediate_ratio: -2.2677787876568734
# Current sample: [-0.7220121   0.89568869] chain 9, sample 9
# log dataset likelihood: -226.77787876568735, intermediate_ratio: -2.2677787876568734
# Current sample: [-0.71697082  0.87715441] chain 9, sample 10
# log dataset likelihood: -227.12390198277595, intermediate_ratio: -2.2712390198277594
# Current sample: [-0.71697082  0.87715441] chain 9, sample 11
# log dataset likelihood: -227.12390198277595, intermediate_ratio: -2.2712390198277594
# Current sample: [-0.71697082  0.87715441] chain 9, sample 12
# log dataset likelihood: -227.12390198277595, intermediate_ratio: -2.2712390198277594
# Current sample: [-0.71697082  0.87715441] chain 9, sample 13
# log dataset likelihood: -227.12390198277595, intermediate_ratio: -2.2712390198277594
# Current sample: [-0.72574052  0.89169615] chain 9, sample 14
# log dataset likelihood: -227.19744880293328, intermediate_ratio: -2.2719744880293327
# Current sample: [-0.72574052  0.89169615] chain 9, sample 15
# log dataset likelihood: -227.19744880293328, intermediate_ratio: -2.2719744880293327
# Current sample: [-0.69797267  0.88174129] chain 9, sample 16
# log dataset likelihood: -226.3160959755204, intermediate_ratio: -2.263160959755204
# Current sample: [-0.69797267  0.88174129] chain 9, sample 17
# log dataset likelihood: -226.3160959755204, intermediate_ratio: -2.263160959755204
# Current sample: [-0.69797267  0.88174129] chain 9, sample 18
# log dataset likelihood: -226.3160959755204, intermediate_ratio: -2.263160959755204
# Current sample: [-0.69797267  0.88174129] chain 9, sample 19
# log dataset likelihood: -226.3160959755204, intermediate_ratio: -2.263160959755204
# Current sample: [-0.69797267  0.88174129] chain 9, sample 20
# log dataset likelihood: -226.3160959755204, intermediate_ratio: -2.263160959755204
# Current sample: [-0.69797267  0.88174129] chain 9, sample 21
# log dataset likelihood: -226.3160959755204, intermediate_ratio: -2.263160959755204
# Current sample: [-0.69797267  0.88174129] chain 9, sample 22
# log dataset likelihood: -226.3160959755204, intermediate_ratio: -2.263160959755204
# Current sample: [-0.69797267  0.88174129] chain 9, sample 23
# log dataset likelihood: -226.3160959755204, intermediate_ratio: -2.263160959755204
# Current sample: [-0.69797267  0.88174129] chain 9, sample 24
# log dataset likelihood: -226.3160959755204, intermediate_ratio: -2.263160959755204
# Current sample: [-0.68512298  0.92182987] chain 9, sample 25
# log dataset likelihood: -226.92817883547482, intermediate_ratio: -2.2692817883547485
# Current sample: [-0.68512298  0.92182987] chain 9, sample 26
# log dataset likelihood: -226.92817883547482, intermediate_ratio: -2.2692817883547485
# Current sample: [-0.68512298  0.92182987] chain 9, sample 27
# log dataset likelihood: -226.92817883547482, intermediate_ratio: -2.2692817883547485
# Current sample: [-0.68512298  0.92182987] chain 9, sample 28
# log dataset likelihood: -226.92817883547482, intermediate_ratio: -2.2692817883547485
# Current sample: [-0.68512298  0.92182987] chain 9, sample 29
# log dataset likelihood: -226.92817883547482, intermediate_ratio: -2.2692817883547485
# Current sample: [-0.68512298  0.92182987] chain 9, sample 30
# log dataset likelihood: -226.92817883547482, intermediate_ratio: -2.2692817883547485
# Current sample: [-0.68512298  0.92182987] chain 9, sample 31
# log dataset likelihood: -226.92817883547482, intermediate_ratio: -2.2692817883547485
# Current sample: [-0.68512298  0.92182987] chain 9, sample 32
# log dataset likelihood: -226.92817883547482, intermediate_ratio: -2.2692817883547485
# Current sample: [-0.68512298  0.92182987] chain 9, sample 33
# log dataset likelihood: -226.92817883547482, intermediate_ratio: -2.2692817883547485
# Current sample: [-0.68512298  0.92182987] chain 9, sample 34
# log dataset likelihood: -226.92817883547482, intermediate_ratio: -2.2692817883547485
# Current sample: [-0.68512298  0.92182987] chain 9, sample 35
# log dataset likelihood: -226.92817883547482, intermediate_ratio: -2.2692817883547485
# Current sample: [-0.68512298  0.92182987] chain 9, sample 36
# log dataset likelihood: -226.92817883547482, intermediate_ratio: -2.2692817883547485
# Current sample: [-0.68512298  0.92182987] chain 9, sample 37
# log dataset likelihood: -226.92817883547482, intermediate_ratio: -2.2692817883547485
# Current sample: [-0.68512298  0.92182987] chain 9, sample 38
# log dataset likelihood: -226.92817883547482, intermediate_ratio: -2.2692817883547485
# Current sample: [-0.68512298  0.92182987] chain 9, sample 39
# log dataset likelihood: -226.92817883547482, intermediate_ratio: -2.2692817883547485
# Current sample: [-0.68512298  0.92182987] chain 9, sample 40
# log dataset likelihood: -226.92817883547482, intermediate_ratio: -2.2692817883547485
# Current sample: [-0.68512298  0.92182987] chain 9, sample 41
# log dataset likelihood: -226.92817883547482, intermediate_ratio: -2.2692817883547485
# Current sample: [-0.69336916  0.91705745] chain 9, sample 42
# log dataset likelihood: -226.3130806589546, intermediate_ratio: -2.263130806589546
# Current sample: [-0.7092292   0.91876604] chain 9, sample 43
# log dataset likelihood: -226.52301350550587, intermediate_ratio: -2.265230135055059
# Current sample: [-0.7092292   0.91876604] chain 9, sample 44
# log dataset likelihood: -226.52301350550587, intermediate_ratio: -2.265230135055059
# Current sample: [-0.7092292   0.91876604] chain 9, sample 45
# log dataset likelihood: -226.52301350550587, intermediate_ratio: -2.265230135055059
# Current sample: [-0.7092292   0.91876604] chain 9, sample 46
# log dataset likelihood: -226.52301350550587, intermediate_ratio: -2.265230135055059
# Current sample: [-0.70025936  0.88221328] chain 9, sample 47
# log dataset likelihood: -226.2770047720696, intermediate_ratio: -2.262770047720696
# Current sample: [-0.70025936  0.88221328] chain 9, sample 48
# log dataset likelihood: -226.2770047720696, intermediate_ratio: -2.262770047720696
# Current sample: [-0.70025936  0.88221328] chain 9, sample 49
# log dataset likelihood: -226.2770047720696, intermediate_ratio: -2.262770047720696
# Current sample: [-0.70025936  0.88221328] chain 9, sample 50
# log dataset likelihood: -226.2770047720696, intermediate_ratio: -2.262770047720696
# Current sample: [-0.70025936  0.88221328] chain 9, sample 51
# log dataset likelihood: -226.2770047720696, intermediate_ratio: -2.262770047720696
# Current sample: [-0.70025936  0.88221328] chain 9, sample 52
# log dataset likelihood: -226.2770047720696, intermediate_ratio: -2.262770047720696
# Current sample: [-0.70025936  0.88221328] chain 9, sample 53
# log dataset likelihood: -226.2770047720696, intermediate_ratio: -2.262770047720696
# Current sample: [-0.70025936  0.88221328] chain 9, sample 54
# log dataset likelihood: -226.2770047720696, intermediate_ratio: -2.262770047720696
# Current sample: [-0.70025936  0.88221328] chain 9, sample 55
# log dataset likelihood: -226.2770047720696, intermediate_ratio: -2.262770047720696
# Current sample: [-0.70025936  0.88221328] chain 9, sample 56
# log dataset likelihood: -226.2770047720696, intermediate_ratio: -2.262770047720696
# Current sample: [-0.68541593  0.91118081] chain 9, sample 57
# log dataset likelihood: -226.38973974062614, intermediate_ratio: -2.2638973974062613
# Current sample: [-0.68541593  0.91118081] chain 9, sample 58
# log dataset likelihood: -226.38973974062614, intermediate_ratio: -2.2638973974062613
# Current sample: [-0.71914532  0.89977427] chain 9, sample 59
# log dataset likelihood: -226.5240123561177, intermediate_ratio: -2.265240123561177
# Current sample: [-0.69885232  0.87088465] chain 9, sample 60
# log dataset likelihood: -227.1002792085848, intermediate_ratio: -2.271002792085848
# Current sample: [-0.69885232  0.87088465] chain 9, sample 61
# log dataset likelihood: -227.1002792085848, intermediate_ratio: -2.271002792085848
# Current sample: [-0.69885232  0.87088465] chain 9, sample 62
# log dataset likelihood: -227.1002792085848, intermediate_ratio: -2.271002792085848
# Current sample: [-0.69885232  0.87088465] chain 9, sample 63
# log dataset likelihood: -227.1002792085848, intermediate_ratio: -2.271002792085848
# Current sample: [-0.69885232  0.87088465] chain 9, sample 64
# log dataset likelihood: -227.1002792085848, intermediate_ratio: -2.271002792085848
# Current sample: [-0.69885232  0.87088465] chain 9, sample 65
# log dataset likelihood: -227.1002792085848, intermediate_ratio: -2.271002792085848
# Current sample: [-0.69885232  0.87088465] chain 9, sample 66
# log dataset likelihood: -227.1002792085848, intermediate_ratio: -2.271002792085848
# Current sample: [-0.66173206  0.86932805] chain 9, sample 67
# log dataset likelihood: -230.3028282186346, intermediate_ratio: -2.303028282186346
# Current sample: [-0.66173206  0.86932805] chain 9, sample 68
# log dataset likelihood: -230.3028282186346, intermediate_ratio: -2.303028282186346
# Current sample: [-0.66173206  0.86932805] chain 9, sample 69
# log dataset likelihood: -230.3028282186346, intermediate_ratio: -2.303028282186346
# Current sample: [-0.66173206  0.86932805] chain 9, sample 70
# log dataset likelihood: -230.3028282186346, intermediate_ratio: -2.303028282186346
# Current sample: [-0.66173206  0.86932805] chain 9, sample 71
# log dataset likelihood: -230.3028282186346, intermediate_ratio: -2.303028282186346
# Current sample: [-0.66173206  0.86932805] chain 9, sample 72
# log dataset likelihood: -230.3028282186346, intermediate_ratio: -2.303028282186346
# Current sample: [-0.66173206  0.86932805] chain 9, sample 73
# log dataset likelihood: -230.3028282186346, intermediate_ratio: -2.303028282186346
# Current sample: [-0.70081156  0.8269617 ] chain 9, sample 74
# log dataset likelihood: -233.98164356168726, intermediate_ratio: -2.3398164356168727
# Current sample: [-0.70081156  0.8269617 ] chain 9, sample 75
# log dataset likelihood: -233.98164356168726, intermediate_ratio: -2.3398164356168727
# Current sample: [-0.70081156  0.8269617 ] chain 9, sample 76
# log dataset likelihood: -233.98164356168726, intermediate_ratio: -2.3398164356168727
# Current sample: [-0.66325481  0.97961661] chain 9, sample 77
# log dataset likelihood: -237.88845595714906, intermediate_ratio: -2.3788845595714907
# Current sample: [-0.66325481  0.97961661] chain 9, sample 78
# log dataset likelihood: -237.88845595714906, intermediate_ratio: -2.3788845595714907
# Current sample: [-0.65757639  0.99296692] chain 9, sample 79
# log dataset likelihood: -242.20834589215897, intermediate_ratio: -2.42208345892159
# Current sample: [-0.74600922  0.90167607] chain 9, sample 80
# log dataset likelihood: -230.03838139643395, intermediate_ratio: -2.3003838139643396
# Current sample: [-0.74600922  0.90167607] chain 9, sample 81
# log dataset likelihood: -230.03838139643395, intermediate_ratio: -2.3003838139643396
# Current sample: [-0.74600922  0.90167607] chain 9, sample 82
# log dataset likelihood: -230.03838139643395, intermediate_ratio: -2.3003838139643396
# Current sample: [-0.64343263  0.88959711] chain 9, sample 83
# log dataset likelihood: -232.42615717543111, intermediate_ratio: -2.3242615717543114
# Current sample: [-0.7651104   0.94686999] chain 9, sample 84
# log dataset likelihood: -238.00198115891357, intermediate_ratio: -2.380019811589136
# Current sample: [-0.73088017  0.88859433] chain 9, sample 85
# log dataset likelihood: -227.85720612592002, intermediate_ratio: -2.2785720612592004
# Current sample: [-0.69178066  0.95643167] chain 9, sample 86
# log dataset likelihood: -230.7648547772849, intermediate_ratio: -2.3076485477728492
# Current sample: [-0.69178066  0.95643167] chain 9, sample 87
# log dataset likelihood: -230.7648547772849, intermediate_ratio: -2.3076485477728492
# Current sample: [-0.70245853  0.9064354 ] chain 9, sample 88
# log dataset likelihood: -225.8689190018648, intermediate_ratio: -2.2586891900186483
# Current sample: [-0.70245853  0.9064354 ] chain 9, sample 89
# log dataset likelihood: -225.8689190018648, intermediate_ratio: -2.2586891900186483
# Current sample: [-0.70245853  0.9064354 ] chain 9, sample 90
# log dataset likelihood: -225.8689190018648, intermediate_ratio: -2.2586891900186483
# Current sample: [-0.70245853  0.9064354 ] chain 9, sample 91
# log dataset likelihood: -225.8689190018648, intermediate_ratio: -2.2586891900186483
# Current sample: [-0.70245853  0.9064354 ] chain 9, sample 92
# log dataset likelihood: -225.8689190018648, intermediate_ratio: -2.2586891900186483
# Current sample: [-0.70245853  0.9064354 ] chain 9, sample 93
# log dataset likelihood: -225.8689190018648, intermediate_ratio: -2.2586891900186483
# Current sample: [-0.70245853  0.9064354 ] chain 9, sample 94
# log dataset likelihood: -225.8689190018648, intermediate_ratio: -2.2586891900186483
# Current sample: [-0.7855377   0.97189853] chain 9, sample 95
# log dataset likelihood: -249.0859220912885, intermediate_ratio: -2.490859220912885
# Current sample: [-0.64611431  0.9507935 ] chain 9, sample 96
# log dataset likelihood: -235.2424694513982, intermediate_ratio: -2.352424694513982
# Current sample: [-0.68384647  0.92407736] chain 9, sample 97
# log dataset likelihood: -227.1584142138045, intermediate_ratio: -2.271584142138045
# Current sample: [-0.64019947  0.9871765 ] chain 9, sample 98
# log dataset likelihood: -244.0100331336732, intermediate_ratio: -2.440100331336732
# Current sample: [-0.86894124  0.96067668] chain 9, sample 99
# log dataset likelihood: -289.72856308958717, intermediate_ratio: -2.8972856308958717
# Current sample: [-0.63592084  0.75330734] chain 9, sample 100
# log dataset likelihood: -268.16340193256576, intermediate_ratio: -2.681634019325658
# Finished simulating chain, omega sample is: 2.093853653218774e-100, log omega: -229.51950307802377
# [5.172961124668158e-101, 3.7931151458180055e-101, 1.622762957002031e-100, 1.7870648497837052e-100, 1.6355328520683327e-100, 2.405327004969194e-101, 1.3659024583959654e-101, 8.548805767334861e-101, 2.1193903329892665e-101, 2.093853653218774e-100]
# ML estimate: 9.479764495490388e-101
# Log ML estimate: -230.3119349186881
